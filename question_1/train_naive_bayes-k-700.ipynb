# %%
import pandas as pd
import numpy as np

import joblib
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
def train_naive_bayes(labels,unique_classes, bag_of_words):   

    prior_prob = np.empty(len(labels))
    vocab = []
    words_in_label = np.empty(len(labels))
    for label_index,label in enumerate(unique_classes):
        prior_prob[label_index] = np.sum(labels == label) / float(len(labels))
        words_in_label[label_index]=np.sum(np.array(list(bag_of_words[label_index].values())))
        vocab += bag_of_words[label_index].keys()
    vocab = np.unique(np.array(vocab))
    likelihood_dividor = np.array([words_in_label[label_index]+len(vocab) for label_index, label in enumerate(unique_classes)])
    lookup_table =[]
    for label_index, label in enumerate(unique_classes):
        lookup_table.append((bag_of_words[label_index],prior_prob[label_index],likelihood_dividor[label_index]))
    return lookup_table

# %%
# 80 20

bag_of_wrds_80_20 = joblib.load("selected_features_80_20_k_700")
train_80_20 = pd.read_csv("train_80_20_split.csv")
test_80_20 = pd.read_csv("test_80_20_split.csv")
LE = preprocessing.LabelEncoder()
train_80_20['label'] = LE.fit_transform(train_80_20['label'].values)
lookup_table_80_20 = train_naive_bayes(train_80_20['label'].values, list(set(train_80_20['label'].values)), bag_of_wrds_80_20)

# %%
lookup_table_80_20
# Out:
# [({'jpeg': 673,
#    'graphic': 538,
#    'image': 1562,
#    'gif': 331,
#    'pixel': 151,
#    'tiff': 132,
#    'polygon': 129,
#    'xv': 112,
#    'animation': 111,
#    'conversion': 110,
#    'output': 104,
#    'shareware': 101,
#    'viewer': 175,
#    'quicktime': 94,
#    'amiga': 92,
#    'sgi': 88,
#    'mac': 153,
#    'directory': 153,
#    'interface': 84,
#    'compression': 82,
#    'ftp': 254,
#    'postscript': 79,
#    'zip': 78,
#    'workstation': 78,
#    'vesa': 78,
#    'visualization': 77,
#    'format': 542,
#    'algorithm': 130,
#    'screen': 126,
#    'driver': 126,
#    'gopher': 71,
#    'vga': 70,
#    'simtel': 69,
#    'archive': 117,
#    'hardware': 116,
#    'rayshade': 66,
#    'phigs': 66,
#    'server': 115,
#    'hacker': 64,
#    'compress': 63,
#    'colour': 110,
#    'quantization': 62,
#    'color': 440,
#    'siggraph': 59,
#    'menu': 59,
#    'filter': 58,
#    'tracer': 57,
#    'interactive': 57,
#    'software': 408,
#    'gifs': 56,
#    'texture': 55,
#    'byte': 55,
#    'version': 389,
#    'pc': 167,
#    'vertex': 51,
#    'card': 160,
#    'macintosh': 50,
#    'cview': 50,
#    'buffer': 50,
#    'archie': 50,
#    'display': 357,
#    'rgb': 49,
#    'converter': 49,
#    'render': 86,
#    'database': 86,
#    'data': 353,
#    'scene': 48,
#    'library': 151,
#    'host': 47,
#    'arithmetic': 46,
#    'utility': 80,
#    'smooth': 45,
#    'dec': 45,
#    'xloadimage': 44,
#    'virtual': 44,
#    'transformation': 44,
#    'photoshop': 44,
#    'frame': 77,
#    'processing': 138,
#    'adobe': 43,
#    'raster': 42,
#    'toolkit': 41,
#    'pov': 41,
#    'lossless': 41,
#    'manipulation': 72,
#    'disk': 71,
#    'processor': 40,
#    'mode': 124,
#    'package': 283,
#    'printer': 39,
#    'demo': 39,
#    'meg': 38,
#    'implementation': 36,
#    'input': 62,
#    'svga': 35,
#    'radiosity': 35,
#    'grayscale': 35,
#    'client': 61,
#    'windows': 34,
#    'ppm': 34,
#    'nfotis': 34,
#    'listing': 34,
#    'linear': 34,
#    'cad': 34,
#    'bitmap': 34,
#    'gamma': 59,
#    'palette': 33,
#    'motif': 33,
#    'code': 237,
#    'convert': 233,
#    'vector': 32,
#    'targa': 32,
#    'msdos': 31,
#    'geometry': 31,
#    'convex': 31,
#    'unix': 97,
#    'plane': 54,
#    'compile': 53,
#    'art': 53,
#    'rle': 30,
#    'pd': 30,
#    'mhz': 30,
#    'linux': 30,
#    'intersection': 30,
#    'fractal': 30,
#    'compatible': 30,
#    'cod': 30,
#    'clip': 30,
#    'arbitrary': 30,
#    'surface': 94,
#    'pub': 29,
#    'ch': 29,
#    'map': 91,
#    'plot': 89,
#    'wireframe': 28,
#    'programming': 28,
#    'lightwave': 28,
#    'fps': 28,
#    'font': 28,
#    'enhancement': 28,
#    'setting': 48,
#    'xx': 27,
#    'spec': 27,
#    'mirror': 83,
#    'xli': 26,
#    'widget': 26,
#    'renderer': 26,
#    'raytracing': 26,
#    'manchester': 26,
#    'geometric': 26,
#    'dither': 26,
#    'abstract': 26,
#    'hp': 45,
#    'object': 184,
#    'routine': 80,
#    'ibm': 79,
#    'manual': 44,
#    'extension': 44,
#    'xyz': 25,
#    'temp': 25,
#    'storage': 25,
#    'pict': 25,
#    'pbmplus': 25,
#    'manipulate': 25,
#    'intensity': 25,
#    'fortran': 25,
#    'download': 25,
#    'digitize': 25,
#    'ascii': 25,
#    'window': 179,
#    'ultra': 24,
#    'silicon': 24,
#    'selection': 24,
#    'scanner': 24,
#    'jpegs': 24,
#    'iris': 24,
#    'hicolor': 24,
#    'gl': 24,
#    'contour': 24,
#    'cclilley': 24,
#    'ati': 24,
#    'documentation': 42,
#    'quality': 170,
#    'sphere': 41,
#    'xwindows': 23,
#    'intersect': 23,
#    'cjpeg': 23,
#    'platform': 72,
#    'quadra': 22,
#    'proprietary': 22,
#    'povray': 22,
#    'portable': 22,
#    'log': 22,
#    'functionality': 22,
#    'dxf': 22,
#    'tool': 158,
#    'video': 157,
#    'fax': 157,
#    'module': 38,
#    'binary': 38,
#    'digital': 67,
#    'mb': 37,
#    'workshop': 21,
#    'vi': 21,
#    'transform': 21,
#    'tga': 21,
#    'modification': 21,
#    'modeling': 21,
#    'alpha': 21,
#    'signal': 36,
#    'default': 36,
#    'readme': 20,
#    'iff': 20,
#    'floppy': 20,
#    'ellipse': 20,
#    'corel': 20,
#    'bmp': 20,
#    'algorithms': 20,
#    'acm': 20,
#    'application': 144,
#    'shade': 35,
#    'online': 61,
#    'telnet': 19,
#    'subroutine': 19,
#    'spline': 19,
#    'quantize': 19,
#    'pex': 19,
#    'patch': 19,
#    'pascal': 19,
#    'modem': 19,
#    'jpg': 19,
#    'graeme': 19,
#    'filename': 19,
#    'import': 32,
#    'width': 18,
#    'tag': 18,
#    'sumex': 18,
#    'pic': 18,
#    'password': 18,
#    'histogram': 18,
#    'graphical': 18,
#    'drawing': 18,
#    'cpu': 18,
#    'alchemy': 18,
#    'ab': 18,
#    'dos': 31,
#    'ray': 126,
#    'model': 123,
#    'zoom': 17,
#    'variable': 17,
#    'tmc': 17,
#    'speedstar': 17,
#    'spatial': 17,
#    'slide': 17,
#    'rtrace': 17,
#    'rend': 17,
#    'raytracer': 17,
#    'playback': 17,
#    'microsoft': 17,
#    'isbn': 17,
#    'install': 17,
#    'indigo': 17,
#    'gem': 17,
#    'ff': 17,
#    'djgpp': 17,
#    'vendor': 29,
#    'modify': 29,
#    'curve': 29,
#    'appreciated': 29,
#    'visualisation': 16,
#    'turbo': 16,
#    'triangle': 16,
#    'specification': 16,
#    'prompt': 16,
#    'pcx': 16,
#    'overlay': 16,
#    'matrix': 16,
#    'lewis': 16,
#    'fotis': 16,
#    'diagram': 16,
#    'contrib': 16,
#    'comp': 16,
#    'ave': 16,
#    'parameter': 28,
#    'parallel': 28,
#    'header': 28,
#    'scale': 50,
#    'port': 50,
#    'command': 50,
#    'analysis': 114,
#    'edit': 49,
#    'compute': 49,
#    'upgrade': 27,
#    'raw': 27,
#    'protocol': 27,
#    'graph': 27,
#    'crop': 27,
#    'bbs': 27,
#    'feature': 110,
#    'bite': 48,
#    'wuarchive': 15,
#    'super': 15,
#    'seminar': 15,
#    'polyhedron': 15,
#    'optimize': 15,
#    'offset': 15,
#    'netters': 15,
#    'multimedia': 15,
#    'mpeg': 15,
#    'impulse': 15,
#    'imagery': 15,
#    'greece': 15,
#    'ethic': 15,
#    'decode': 15,
#    'custom': 15,
#    'compressor': 15,
#    'bits': 15,
#    'scan': 47,
#    'resolution': 47,
#    'retrieve': 26,
#    'permission': 26,
#    'trace': 46,
#    'border': 25,
#    'picture': 102,
#    'faq': 102,
#    'thesis': 14,
#    'sparc': 14,
#    'smoothing': 14,
#    'script': 14,
#    'preview': 14,
#    'plotter': 14,
#    'parametric': 14,
#    'ntsc': 14,
#    'msdosgraphics': 14,
#    'mathematical': 14,
#    'lisp': 14,
#    'kubota': 14,
#    'khoros': 14,
#    'interpolation': 14,
#    'imagemagick': 14,
#    'graphics': 14,
#    'ftpmail': 14,
#    'bytes': 14,
#    'brightness': 14,
#    'bezier': 14,
#    'beta': 14,
#    'av': 14,
#    'hi': 100,
#    'split': 24,
#    'removal': 24,
#    'enhance': 24,
#    'coordinate': 24,
#    'array': 24,
#    'author': 98,
#    'load': 42,
#    'search': 96,
#    'row': 23,
#    'realtime': 23,
#    'ram': 23,
#    'zbuffer': 13,
#    'xview': 13,
#    'useless': 13,
#    'truecolor': 13,
#    'tofrom': 13,
#    'studio': 13,
#    'robust': 13,
#    'renderman': 13,
#    'quickdraw': 13,
#    'nikolaos': 13,
#    'mesh': 13,
#    'login': 13,
#    'generic': 13,
#    'freeware': 13,
#    'cursor': 13,
#    'cray': 13,
#    'computation': 13,
#    'char': 13,
#    'centris': 13,
#    'bw': 13,
#    'builtin': 13,
#    'bios': 13,
#    'animate': 13,
#    'function': 91,
#    'helpful': 22,
#    'developer': 22,
#    'faster': 39,
#    'implement': 38,
#    'wate': 12,
#    'submission': 12,
#    'scroll': 12,
#    'pl': 12,
#    'oxford': 12,
#    'modeller': 12,
#    'micro': 12,
#    'intermediate': 12,
#    'interactively': 12,
#    'integer': 12,
#    'installation': 12,
#    'grey': 12,
#    'gray': 12,
#    'exe': 12,
#    'eisa': 12,
#    'diamond': 12,
#    'coplanar': 12,
#    'convenience': 12,
#    'computational': 12,
#    'cdrom': 12,
#    'autocad': 12,
#    'saving': 21,
#    'mar': 21,
#    'mapping': 21,
#    'automatically': 21,
#    'artist': 21,
#    'entry': 37,
#    'access': 84,
#    'suite': 36,
#    'vms': 20,
#    'thanx': 20,
#    'pointer': 20,
#    'orient': 20,
#    'nasa': 20,
#    'measurement': 20,
#    'sequence': 35,
#    'presentation': 35,
#    'index': 35,
#    'copyright': 35,
#    'text': 80,
#    'copy': 80,
#    'winjpeg': 11,
#    'toaster': 11,
#    'stream': 11,
#    'sprite': 11,
#    'risc': 11,
#    'procedural': 11,
#    'precision': 11,
#    'pbm': 11,
#    'os': 11,
#    'oo': 11,
#    'obsolete': 11,
#    'nonlinear': 11,
#    'modeler': 11,
#    'licence': 11,
#    'lcd': 11,
#    'kernel': 11,
#    'hardcopy': 11,
#    'grid': 11,
#    'fli': 11,
#    'dot': 11,
#    'distinct': 11,
#    'detection': 11,
#    'decompression': 11,
#    'daemon': 11,
#    'cube': 11,
#    'convolution': 11,
#    'composite': 11,
#    'chapel': 11,
#    'antialiasing': 11,
#    'ansi': 11,
#    'amigas': 11,
#    'simulation': 19,
#    'hidden': 19,
#    'calculation': 19,
#    'define': 78,
#    'utah': 34,
#    'centre': 34,
#    'programmer': 33,
#    'australia': 33,
#    'sender': 18,
#    'registration': 18,
#    'mouse': 18,
#    'lab': 32,
#    'electronic': 32,
#    'yeh': 10,
#    'upload': 10,
#    'translate': 10,
#    'threedimensional': 10,
#    'starter': 10,
#    'sparcstation': 10,
#    'running': 10,
#    'ricardo': 10,
#    'rene': 10,
#    'rectangular': 10,
#    'paste': 10,
#    'multiverse': 10,
#    'morph': 10,
#    'lookup': 10,
#    'lilley': 10,
#    'keyboard': 10,
#    'juhana': 10,
#    'joachim': 10,
#    'itti': 10,
#    'irit': 10,
#    'illustrator': 10,
#    'hsv': 10,
#    'highend': 10,
#    'hex': 10,
#    'gnu': 10,
#    'dogfight': 10,
#    'dir': 10,
#    'complicated': 10,
#    'clock': 10,
#    'cgm': 10,
#    'cdroms': 10,
#    'buggy': 10,
#    'bitspixel': 10,
#    'alias': 10,
#    'vision': 31,
#    'flexible': 17,
#    'export': 17,
#    'defect': 17,
#    'compiler': 17,
#    'calculate': 17,
#    'axis': 17,
#    'capture': 30,
#    'various': 68,
#    'subscribe': 29,
#    'register': 29,
#    'proceeding': 16,
#    'max': 16,
#    'instruction': 16,
#    'doc': 16,
#    'worley': 9,
#    'widespread': 9,
#    'warranty': 9,
#    'vpic': 9,
#    'usc': 9,
#    'trivial': 9,
#    'translator': 9,
#    'supercomputer': 9,
#    'straightforward': 9,
#    'standalone': 9,
#    'spl': 9,
#    'sloan': 9,
#    'slice': 9,
#    'sgis': 9,
#    'scsi': 9,
#    'refresh': 9,
#    'reflection': 9,
#    'raytraced': 9,
#    'query': 9,
#    'qt': 9,
#    'qrt': 9,
#    'publisher': 9,
#    'oak': 9,
#    'kouhia': 9,
#    'kit': 9,
#    'iraf': 9,
#    'infinite': 9,
#    'img': 9,
#    'hollasch': 9,
#    'gradient': 9,
#    'gnuplot': 9,
#    'gaussian': 9,
#    'flip': 9,
#    'delaunay': 9,
#    'decoder': 9,
#    'darn': 9,
#    'cshow': 9,
#    'coreldraw': 9,
#    'configure': 9,
#    'concave': 9,
#    'computing': 9,
#    'boundary': 9,
#    'autodesk': 9,
#    'atari': 9,
#    'artifact': 9,
#    'archimedes': 9,
#    'aix': 9,
#    'uk': 28,
#    'specify': 28,
#    'select': 28,
#    'useful': 64,
#    'page': 63,
#    'imaging': 27,
#    'character': 27,
#    'bus': 27,
#    'trick': 15,
#    'pp': 15,
#    'integrate': 15,
#    'athens': 15,
#    'bug': 61,
#    'cd': 26,
#    'anonymous': 58,
#    'xy': 8,
#    'vr': 8,
#    'viewing': 8,
#    'username': 8,
#    'triangulation': 8,
#    'terrain': 8,
#    'sutherland': 8,
#    'subdirectory': 8,
#    'stereo': 8,
#    'starbase': 8,
#    'rep': 8,
#    'reasonably': 8,
#    'realworld': 8,
#    'photographic': 8,
#    'phong': 8,
#    'numerical': 8,
#    'ne': 8,
#    'loop': 8,
#    'limitation': 8,
#    'layout': 8,
#    'ithaca': 8,
#    'isa': 8,
#    'irix': 8,
#    'io': 8,
#    'hpux': 8,
#    'highresolution': 8,
#    'gui': 8,
#    'gr': 8,
#    'gill': 8,
#    'fullscreen': 8,
#    'facet': 8,
#    'distributed': 8,
#    'dimensional': 8,
#    'decs': 8,
#    'dam': 8,
#    'cyberware': 8,
#    'cboesel': 8,
#    'cb': 8,
#    'bundle': 8,
#    'browse': 8,
#    'boesel': 8,
#    'blur': 8,
#    'asm': 8,
#    'artwork': 8,
#    'architecture': 8,
#    'aldus': 8,
#    'translation': 14,
#    'spectrum': 14,
#    'radius': 14,
#    'node': 14,
#    'generator': 14,
#    'controller': 14,
#    'automatic': 14,
#    'assembly': 14,
#    'monitor': 56,
#    'device': 56,
#    'environment': 55,
#    'visible': 24,
#    'photograph': 24,
#    'forum': 24,
#    'distance': 24,
#    'chip': 24,
#    'method': 54,
#    'projection': 13,
#    'peripheral': 13,
#    'optional': 13,
#    'motorola': 13,
#    'kevin': 13,
#    'integration': 13,
#    'grasp': 13,
#    'cylinder': 13,
#    'compressed': 13,
#    'complicate': 13,
#    'complexity': 13,
#    'cambridge': 13,
#    'angle': 23,
#    'resource': 52,
#    'capability': 52,
#    'undocumented': 7,
#    'trident': 7,
#    'tricky': 7,
#    'sunview': 7,
#    'sophisticated': 7,
#    'softwarehardware': 7,
#    'snail': 7,
#    'simplify': 7,
#    'sigma': 7,
#    'serial': 7,
#    'runtime': 7,
#    'rudimentry': 7,
#    'rom': 7,
#    'representation': 7,
#    'renew': 7,
#    'rendering': 7,
#    'readwrite': 7,
#    'readingwriting': 7,
#    'pubmsdosgraphics': 7,
#    'publicdomain': 7,
#    'pixar': 7,
#    'philip': 7,
#    'pgm': 7,
#    'pal': 7,
#    'mips': 7,
#    'mcsunariadnetheseasnfotis': 7,
#    'matrox': 7,
#    'lowlevel': 7,
#    'lowend': 7,
#    'landscape': 7,
#    'lamont': 7,
#    'kyanko': 7,
#    'keyword': 7,
#    'invoke': 7,
#    'intel': 7,
#    'ieee': 7,
#    'icon': 7,
#    'halandri': 7,
#    'greeting': 7},
#   0.20025,
#   30364.0),
#  ({'hockey': 655,
#    'season': 393,
#    'playoff': 357,
#    'nhl': 350,
#    'espn': 193,
#    'det': 187,
#    'detroit': 184,
#    'coach': 165,
#    'score': 284,
#    'montreal': 161,
#    'bos': 159,
#    'league': 278,
#    'pt': 272,
#    'cup': 267,
#    'tor': 144,
#    'pen': 144,
#    'chi': 144,
#    'buffalo': 144,
#    'team': 1010,
#    'goalie': 135,
#    'bruin': 133,
#    'nyi': 131,
#    'gm': 229,
#    'calgary': 129,
#    'shark': 124,
#    'puck': 121,
#    'penguin': 120,
#    'islander': 120,
#    'devil': 120,
#    'que': 119,
#    'buf': 116,
#    'pit': 196,
#    'stl': 110,
#    'fan': 344,
#    'ranger': 190,
#    'penalty': 182,
#    'sabre': 102,
#    'oiler': 100,
#    'baseball': 100,
#    'leaf': 175,
#    'lemieux': 99,
#    'edmonton': 97,
#    'ahl': 96,
#    'mario': 92,
#    'canuck': 92,
#    'nyr': 91,
#    'captain': 91,
#    'jose': 90,
#    'ottawa': 81,
#    'fuhr': 81,
#    'abc': 81,
#    'cal': 142,
#    'sj': 80,
#    'scorer': 79,
#    'gretzky': 78,
#    'arena': 78,
#    'stanley': 137,
#    'pp': 137,
#    'draft': 136,
#    'champ': 76,
#    'sweden': 75,
#    'skate': 75,
#    'norris': 75,
#    'hawk': 74,
#    'phi': 73,
#    'edm': 73,
#    'ot': 71,
#    'wing': 213,
#    'win': 486,
#    'quebec': 118,
#    'jersey': 67,
#    'gilmour': 67,
#    'finland': 67,
#    'winnipeg': 117,
#    'ott': 66,
#    'defenseman': 66,
#    'lindros': 64,
#    'tampa': 62,
#    'har': 61,
#    'louis': 106,
#    'boston': 190,
#    'maynard': 60,
#    'jagr': 60,
#    'francis': 60,
#    'roger': 105,
#    'pittsburgh': 187,
#    'min': 104,
#    'stats': 59,
#    'overtime': 59,
#    'moncton': 59,
#    'potvin': 58,
#    'adirondack': 58,
#    'goaltender': 57,
#    'canadiens': 56,
#    'smythe': 55,
#    'goal': 390,
#    'powerplay': 54,
#    'hartford': 53,
#    'habs': 53,
#    'bure': 53,
#    'ulf': 52,
#    'defensive': 52,
#    'minnesota': 91,
#    'sport': 88,
#    'championship': 50,
#    'mtl': 48,
#    'gainey': 48,
#    'king': 151,
#    'ice': 150,
#    'whaler': 47,
#    'providence': 47,
#    'lw': 47,
#    'selanne': 82,
#    'springfield': 46,
#    'franchise': 46,
#    'van': 143,
#    'tb': 79,
#    'utica': 44,
#    'rw': 44,
#    'njd': 44,
#    'binghamton': 44,
#    'flyer': 76,
#    'isle': 43,
#    'cherry': 43,
#    'murray': 74,
#    'standing': 42,
#    'mogilny': 42,
#    'pts': 41,
#    'lafontaine': 41,
#    'finnish': 41,
#    'en': 41,
#    'breton': 41,
#    'philadelphia': 72,
#    'bay': 71,
#    'tournament': 40,
#    'probert': 40,
#    'pitt': 40,
#    'blackhawks': 40,
#    'la': 275,
#    'keenan': 38,
#    'hextall': 38,
#    'dineen': 38,
#    'gerald': 66,
#    'tie': 117,
#    'angeles': 65,
#    'savard': 37,
#    'kariya': 37,
#    'stevens': 36,
#    'ihl': 36,
#    'czech': 36,
#    'barrasso': 36,
#    'nj': 112,
#    'canadian': 112,
#    'victory': 35,
#    'pocklington': 35,
#    'murphy': 35,
#    'fredericton': 35,
#    'ecac': 35,
#    'bowman': 35,
#    'champion': 61,
#    'yzerman': 34,
#    'swedish': 34,
#    'cbc': 34,
#    'bruins': 34,
#    'shot': 240,
#    'sutter': 33,
#    'rsh': 33,
#    'rookie': 33,
#    'hull': 33,
#    'fleury': 33,
#    'coffey': 33,
#    'chelios': 33,
#    'calder': 33,
#    'attendance': 33,
#    'mon': 102,
#    'wc': 31,
#    'neely': 31,
#    'hunter': 31,
#    'halifax': 31,
#    'cdi': 31,
#    'rochester': 54,
#    'gld': 53,
#    'trophy': 30,
#    'tocchet': 30,
#    'soderstrom': 30,
#    'slash': 30,
#    'shanahan': 30,
#    'sh': 30,
#    'mullen': 30,
#    'messier': 30,
#    'maine': 30,
#    'hrivnak': 30,
#    'hammerl': 30,
#    'courtnall': 30,
#    'patrick': 94,
#    'talent': 52,
#    'sandstrom': 29,
#    'sanderson': 29,
#    'pim': 29,
#    'pgh': 29,
#    'scoring': 28,
#    'referee': 28,
#    'penguins': 28,
#    'oates': 28,
#    'denis': 28,
#    'rauser': 27,
#    'nordiques': 27,
#    'milwaukee': 27,
#    'cgy': 27,
#    'carson': 27,
#    'belfour': 27,
#    'coverage': 85,
#    'watch': 193,
#    'cap': 83,
#    'kevin': 46,
#    'acquire': 46,
#    'vernon': 26,
#    'stauber': 26,
#    'semifinal': 26,
#    'roster': 26,
#    'quinn': 26,
#    'offense': 26,
#    'nords': 26,
#    'moog': 26,
#    'macinnis': 26,
#    'johansson': 26,
#    'cordially': 26,
#    'tsn': 25,
#    'robitaille': 25,
#    'octopus': 25,
#    'breaker': 25,
#    'bellow': 25,
#    'andersson': 25,
#    'senator': 43,
#    'mighty': 24,
#    'miami': 24,
#    'linden': 24,
#    'kovalev': 24,
#    'kisio': 24,
#    'goaltending': 24,
#    'disappointment': 24,
#    'bobby': 24,
#    'mask': 42,
#    'trade': 171,
#    'ticket': 41,
#    'cape': 41,
#    'wpg': 23,
#    'teemu': 23,
#    'selnne': 23,
#    'roenick': 23,
#    'randy': 23,
#    'defensemen': 23,
#    'damphousse': 23,
#    'bettman': 23,
#    'roy': 72,
#    'mvp': 40,
#    'expansion': 40,
#    'vs': 71,
#    'night': 162,
#    'winner': 70,
#    'suck': 39,
#    'deserve': 39,
#    'toronto': 160,
#    'turgeon': 22,
#    'slot': 22,
#    'phoenix': 22,
#    'nelson': 22,
#    'ncaa': 22,
#    'hawerchuk': 22,
#    'ferraro': 22,
#    'bourque': 22,
#    'announcer': 22,
#    'jet': 157,
#    'wayne': 37,
#    'suter': 21,
#    'ronning': 21,
#    'nylander': 21,
#    'moron': 21,
#    'keller': 21,
#    'golf': 21,
#    'basketball': 21,
#    'asshole': 21,
#    'streak': 20,
#    'staffan': 20,
#    'rating': 20,
#    'norway': 20,
#    'mcgill': 20,
#    'kelly': 20,
#    'granato': 20,
#    'gartner': 20,
#    'fame': 20,
#    'essensa': 20,
#    'daigle': 20,
#    'clarkson': 20,
#    'championships': 20,
#    'bench': 20,
#    'austria': 20,
#    'vancouver': 144,
#    'injury': 60,
#    'stewart': 19,
#    'quaker': 19,
#    'otto': 19,
#    'lak': 19,
#    'kurri': 19,
#    'kansas': 19,
#    'juneau': 19,
#    'janney': 19,
#    'hrudey': 19,
#    'housley': 19,
#    'hart': 19,
#    'gtd': 19,
#    'friedman': 19,
#    'dchhabra': 19,
#    'brindamour': 19,
#    'bri': 19,
#    'bassen': 19,
#    'allstar': 19,
#    'rm': 33,
#    'chicago': 134,
#    'capital': 58,
#    'zombo': 18,
#    'vezina': 18,
#    'reichel': 18,
#    'ranford': 18,
#    'panther': 18,
#    'niedermayer': 18,
#    'matchup': 18,
#    'foul': 18,
#    'fin': 18,
#    'euro': 18,
#    'domi': 31,
#    'maple': 55,
#    'yawney': 17,
#    'unassisted': 17,
#    'telecast': 17,
#    'swe': 17,
#    'shutout': 17,
#    'samuelsson': 17,
#    'rychel': 17,
#    'recchi': 17,
#    'ramsey': 17,
#    'patton': 17,
#    'nieuwendyk': 17,
#    'kkeller': 17,
#    'junior': 17,
#    'jpc': 17,
#    'ivy': 17,
#    'hornet': 17,
#    'farenell': 17,
#    'farenebt': 17,
#    'curtis': 17,
#    'crease': 17,
#    'contender': 17,
#    'clement': 17,
#    'bradley': 17,
#    'andreychuk': 17,
#    'affiliate': 17,
#    'round': 121,
#    'offensive': 29,
#    'club': 52,
#    'zubov': 16,
#    'winger': 16,
#    'televise': 16,
#    'sundin': 16,
#    'stein': 16,
#    'sportschannel': 16,
#    'selannes': 16,
#    'retire': 16,
#    'pavel': 16,
#    'olympic': 16,
#    'neck': 16,
#    'leafs': 16,
#    'howe': 16,
#    'gregmeister': 16,
#    'graf': 16,
#    'football': 16,
#    'espns': 16,
#    'eklund': 16,
#    'donnelly': 16,
#    'dino': 16,
#    'demers': 16,
#    'daryl': 16,
#    'consecutive': 16,
#    'cheveldae': 16,
#    'blade': 16,
#    'axelsson': 16,
#    'ahlnewsrequest': 16,
#    'admiral': 16,
#    'wood': 27,
#    'miller': 27,
#    'campbell': 27,
#    'vincent': 15,
#    'swede': 15,
#    'sg': 15,
#    'robbie': 15,
#    'replay': 15,
#    'playing': 15,
#    'muller': 15,
#    'millen': 15,
#    'mclean': 15,
#    'mceachern': 15,
#    'markus': 15,
#    'malarchuk': 15,
#    'jokerit': 15,
#    'jay': 15,
#    'glens': 15,
#    'galley': 15,
#    'flatley': 15,
#    'etxonss': 15,
#    'emerson': 15,
#    'defensively': 15,
#    'awesome': 15,
#    'tommy': 26,
#    'italy': 26,
#    'imo': 26,
#    'gp': 26,
#    'bryan': 26,
#    'baltimore': 46,
#    'seat': 25,
#    'michigan': 25,
#    'injure': 25,
#    'dominate': 25,
#    'zhamnov': 14,
#    'willis': 14,
#    'valerie': 14,
#    'tps': 14,
#    'smehlik': 14,
#    'skrudland': 14,
#    'semak': 14,
#    'rink': 14,
#    'poulin': 14,
#    'pederson': 14,
#    'norm': 14,
#    'lu': 14,
#    'kozlov': 14,
#    'kdka': 14,
#    'huot': 14,
#    'honour': 14,
#    'hogue': 14,
#    'glenn': 14,
#    'geoff': 14,
#    'gaudreau': 14,
#    'finn': 14,
#    'dish': 14,
#    'dionne': 14,
#    'craven': 14,
#    'coulman': 14,
#    'ciccarelli': 14,
#    'chuq': 14,
#    'zone': 44,
#    'beat': 99,
#    'rebound': 24,
#    'prediction': 24,
#    'corner': 24,
#    'clark': 24,
#    'grade': 42,
#    'rd': 95,
#    'turner': 23,
#    'republic': 23,
#    'att': 41,
#    'trivia': 13,
#    'tkachuk': 13,
#    'stadium': 13,
#    'praise': 13,
#    'pirate': 13,
#    'paslawski': 13,
#    'naslund': 13,
#    'misconduct': 13,
#    'madden': 13,
#    'maclean': 13,
#    'lapointe': 13,
#    'konstantinov': 13,
#    'khristich': 13,
#    'khmylev': 13,
#    'hype': 13,
#    'hatcher': 13,
#    'goon': 13,
#    'fighting': 13,
#    'fedorov': 13,
#    'dahlquist': 13,
#    'clint': 13,
#    'dallas': 22,
#    'career': 22,
#    'sunday': 39,
#    'ny': 88,
#    'walker': 12,
#    'twoway': 12,
#    'steen': 12,
#    'stat': 12,
#    'stan': 12,
#    'shorthanded': 12,
#    'selke': 12,
#    'roberts': 12,
#    'rheaume': 12,
#    'regularseason': 12,
#    'ppv': 12,
#    'plugger': 12,
#    'philly': 12,
#    'olchowy': 12,
#    'northland': 12,
#    'messy': 12,
#    'mcsorley': 12,
#    'lousy': 12,
#    'ketterer': 12,
#    'jca': 12,
#    'helsinki': 12,
#    'garpenlov': 12,
#    'foligno': 12,
#    'faceoff': 12,
#    'expectation': 12,
#    'est': 12,
#    'escalate': 12,
#    'dynasty': 12,
#    'divisional': 12,
#    'dispersal': 12,
#    'dirty': 12,
#    'cullen': 12,
#    'tm': 21,
#    'tim': 21,
#    'lightning': 21,
#    'tonight': 36,
#    'shit': 20,
#    'felix': 20,
#    'assistant': 20,
#    'defense': 82,
#    'russia': 35,
#    'zelepukin': 11,
#    'umturne': 11,
#    'thorne': 11,
#    'tabaracci': 11,
#    'stretcher': 11,
#    'stiehm': 11,
#    'stephane': 11,
#    'slegge': 11,
#    'skater': 11,
#    'shuchuk': 11,
#    'shawn': 11,
#    'sather': 11,
#    'rod': 11,
#    'preempt': 11,
#    'plusminus': 11,
#    'playoffs': 11,
#    'pearson': 11,
#    'orr': 11,
#    'nba': 11,
#    'musil': 11,
#    'munich': 11,
#    'mikael': 11,
#    'manson': 11,
#    'makarov': 11,
#    'lssu': 11,
#    'lion': 11,
#    'lebeau': 11,
#    'knight': 11,
#    'irbe': 11,
#    'highlight': 11,
#    'golchowy': 11,
#    'gaa': 11,
#    'elynuik': 11,
#    'drake': 11,
#    'defender': 11,
#    'darryl': 11,
#    'coaching': 11,
#    'classy': 11,
#    'burr': 11,
#    'brad': 11,
#    'beezer': 11,
#    'ashton': 11,
#    'anyways': 11,
#    'amonte': 11,
#    'allan': 11,
#    'ali': 11,
#    'sweep': 19,
#    'opponent': 19,
#    'emotional': 19,
#    'defeat': 19,
#    'annoy': 19,
#    'award': 34,
#    'andrew': 34,
#    'wednesday': 18,
#    'settle': 18,
#    'screw': 18,
#    'brett': 18,
#    'alberta': 18,
#    'pool': 32,
#    'whl': 10,
#    'timo': 10,
#    'tikkanen': 10,
#    'sweeney': 10,
#    'stockholm': 10,
#    'saskatoon': 10,
#    'salami': 10,
#    'robb': 10,
#    'reese': 10,
#    'redwing': 10,
#    'primeau': 10,
#    'pivonka': 10,
#    'pilon': 10,
#    'phillie': 10,
#    'petr': 10,
#    'patrik': 10,
#    'nhls': 10,
#    'nedved': 10,
#    'mre': 10,
#    'lange': 10,
#    'kirk': 10,
#    'keenans': 10,
#    'juha': 10,
#    'hardy': 10,
#    'gold': 10,
#    'flames': 10,
#    'felsner': 10,
#    'exciting': 10,
#    'eisler': 10,
#    'duchesne': 10,
#    'derek': 10,
#    'dahlen': 10,
#    'curcio': 10,
#    'cote': 10,
#    'cassels': 10,
#    'carbonneau': 10,
#    'canucks': 10,
#    'brittenson': 10,
#    'breakaway': 10,
#    'boring': 10,
#    'beaupre': 10,
#    'bait': 10,
#    'rush': 17,
#    'roman': 17,
#    'remark': 17,
#    'nicholls': 17,
#    'idiot': 17,
#    'german': 30,
#    'ref': 29,
#    'entry': 29,
#    'wash': 16,
#    'wale': 16,
#    'veteran': 16,
#    'souviens': 16,
#    'slap': 16,
#    'salary': 16,
#    'loser': 16,
#    'je': 16,
#    'impressive': 16,
#    'earn': 16,
#    'dean': 16,
#    'alexander': 16,
#    'zhitnik': 9,
#    'ysebaert': 9,
#    'woofer': 9,
#    'winning': 9,
#    'wdve': 9,
#    'vergolini': 9,
#    'verbeek': 9,
#    'vaske': 9,
#    'vanbiesbrouck': 9,
#    'tomas': 9,
#    'talented': 9,
#    'swiss': 9,
#    'superstar': 9,
#    'soccer': 9,
#    'slump': 9,
#    'shannon': 9,
#    'sergei': 9,
#    'sakic': 9,
#    'ruuttu': 9,
#    'richter': 9,
#    'ricci': 9,
#    'resent': 9,
#    'rain': 9,
#    'penguinsdevils': 9,
#    'oklahoma': 9,
#    'offensively': 9,
#    'numminen': 9,
#    'modo': 9,
#    'mcnall': 9,
#    'lori': 9,
#    'linesman': 9,
#    'lidstrom': 9,
#    'legge': 9,
#    'leetch': 9,
#    'laurie': 9,
#    'lately': 9,
#    'kc': 9,
#    'jarvis': 9,
#    'idacom': 9,
#    'huddy': 9,
#    'hedican': 9,
#    'hayward': 9,
#    'hawgood': 9,
#    'ha': 9,
#    'glove': 9,
#    'genie': 9,
#    'gballent': 9,
#    'falloon': 9,
#    'duck': 9,
#    'druce': 9,
#    'corson': 9,
#    'continent': 9,
#    'coliseum': 9},
#   0.201,
#   33258.0),
#  ({'disease': 380,
#    'infection': 206,
#    'doctor': 344,
#    'hiv': 192,
#    'cancer': 323,
#    'treatment': 272,
#    'drug': 258,
#    'candida': 129,
#    'patient': 406,
#    'yeast': 127,
#    'msg': 213,
#    'symptom': 120,
#    'clinical': 118,
#    'therapy': 107,
#    'quack': 101,
#    'hicnet': 94,
#    'syndrome': 93,
#    'food': 293,
#    'health': 289,
#    'pain': 159,
#    'diet': 156,
#    'cell': 88,
#    'kidney': 82,
#    'sinus': 81,
#    'vitamin': 80,
#    'cure': 79,
#    'vaccine': 77,
#    'illness': 76,
#    'chronic': 74,
#    'antibiotic': 72,
#    'physician': 125,
#    'diagnose': 66,
#    'lyme': 65,
#    'hypothesis': 64,
#    'geb': 64,
#    'fat': 64,
#    'chinese': 64,
#    'newsletter': 112,
#    'hospital': 112,
#    'skepticism': 63,
#    'ear': 63,
#    'breast': 63,
#    'jxp': 61,
#    'intellect': 61,
#    'chastity': 61,
#    'shameful': 60,
#    'prevention': 59,
#    'allergy': 58,
#    'diagnosis': 57,
#    'nutrition': 55,
#    'migraine': 54,
#    'bloom': 54,
#    'medical': 388,
#    'restaurant': 53,
#    'gordon': 93,
#    'severe': 51,
#    'allergic': 51,
#    'immune': 49,
#    'dyer': 49,
#    'trial': 83,
#    'stone': 83,
#    'oral': 47,
#    'medication': 47,
#    'needle': 46,
#    'bone': 46,
#    'antifungal': 46,
#    'photography': 45,
#    'anecdotal': 43,
#    'tissue': 42,
#    'liver': 42,
#    'vaginal': 41,
#    'glutamate': 41,
#    'gi': 41,
#    'calcium': 41,
#    'malaria': 40,
#    'infect': 39,
#    'infant': 39,
#    'cdc': 39,
#    'muscle': 68,
#    'virus': 38,
#    'noring': 37,
#    'empirical': 37,
#    'tobacco': 64,
#    'prescribe': 36,
#    'disorder': 36,
#    'risk': 111,
#    'infectious': 35,
#    'hernia': 35,
#    'gut': 35,
#    'fda': 35,
#    'surrender': 60,
#    'acid': 60,
#    'yogurt': 34,
#    'systemic': 34,
#    'inflammation': 34,
#    'headache': 34,
#    'child': 104,
#    'vagina': 33,
#    'outbreak': 33,
#    'nerve': 33,
#    'milk': 33,
#    'membrane': 33,
#    'intake': 33,
#    'surgeon': 32,
#    'organism': 32,
#    'med': 32,
#    'mg': 56,
#    'russell': 31,
#    'rind': 31,
#    'placebo': 31,
#    'dose': 31,
#    'dietary': 31,
#    'protein': 30,
#    'meat': 30,
#    'kirlian': 30,
#    'hepatitis': 30,
#    'finding': 30,
#    'tract': 29,
#    'water': 91,
#    'mucus': 28,
#    'aura': 28,
#    'substance': 48,
#    'animal': 48,
#    'ultrasound': 27,
#    'react': 27,
#    'pregnancy': 27,
#    'pill': 27,
#    'lung': 27,
#    'ingredient': 27,
#    'clinic': 47,
#    'bacteria': 46,
#    'thyroid': 26,
#    'skin': 81,
#    'taste': 45,
#    'sugar': 25,
#    'stomach': 25,
#    'radiologist': 25,
#    'practitioner': 25,
#    'intestine': 25,
#    'fluid': 25,
#    'antihistamine': 25,
#    'smoking': 24,
#    'nystatin': 24,
#    'fever': 24,
#    'cholesterol': 24,
#    'carl': 24,
#    'additive': 24,
#    'aid': 173,
#    'smoke': 42,
#    'birth': 41,
#    'diabetes': 23,
#    'corn': 23,
#    'biochemistry': 23,
#    'bath': 23,
#    'asthma': 23,
#    'antibody': 23,
#    'acidophilus': 23,
#    'medicine': 164,
#    'surgery': 71,
#    'researcher': 70,
#    'strain': 22,
#    'sensitivity': 22,
#    'massage': 22,
#    'inject': 22,
#    'infj': 22,
#    'discharge': 22,
#    'crohn': 22,
#    'eat': 158,
#    'exercise': 69,
#    'reaction': 68,
#    'remedy': 21,
#    'persistent': 21,
#    'krillean': 21,
#    'diarrhea': 21,
#    'deficiency': 21,
#    'page': 150,
#    'xrays': 20,
#    'tumor': 20,
#    'swell': 20,
#    'supplement': 20,
#    'sporanox': 20,
#    'sensitive': 20,
#    'resistance': 20,
#    'nci': 20,
#    'homeopathy': 20,
#    'fungus': 20,
#    'cream': 20,
#    'banschbach': 20,
#    'amino': 20,
#    'transmission': 35,
#    'dry': 34,
#    'chemical': 60,
#    'nih': 19,
#    'meal': 19,
#    'dominance': 19,
#    'distress': 19,
#    'ct': 19,
#    'human': 136,
#    'healthy': 33,
#    'evidence': 133,
#    'nose': 32,
#    'biology': 32,
#    'surgical': 18,
#    'sting': 18,
#    'prozac': 18,
#    'profession': 18,
#    'obesity': 18,
#    'nutritional': 18,
#    'neuron': 18,
#    'imaharvardrayssdlinusm': 18,
#    'howard': 18,
#    'hivpositive': 18,
#    'glucose': 18,
#    'gland': 18,
#    'genetic': 18,
#    'flavor': 18,
#    'doubleblind': 18,
#    'cspdccdyer': 18,
#    'cereal': 18,
#    'carcinogenic': 18,
#    'biopsy': 18,
#    'bacterial': 18,
#    'approval': 18,
#    'dr': 129,
#    'lab': 55,
#    'advice': 54,
#    'fantasy': 30,
#    'stool': 17,
#    'relieve': 17,
#    'recur': 17,
#    'progression': 17,
#    'painful': 17,
#    'licensed': 17,
#    'lesion': 17,
#    'doyle': 17,
#    'dna': 17,
#    'discomfort': 17,
#    'dentist': 17,
#    'consumption': 17,
#    'albicans': 17,
#    'accepted': 17,
#    'scientific': 120,
#    'treat': 116,
#    'thrush': 16,
#    'steroid': 16,
#    'resident': 16,
#    'olneys': 16,
#    'mri': 16,
#    'kekule': 16,
#    'incidence': 16,
#    'heal': 16,
#    'fruit': 16,
#    'fresh': 16,
#    'burzynskis': 16,
#    'beef': 16,
#    'acute': 16,
#    'tb': 28,
#    'dos': 28,
#    'depression': 28,
#    'seizure': 27,
#    'school': 110,
#    'vaseline': 15,
#    'toxin': 15,
#    'sa': 15,
#    'recurrence': 15,
#    'recipe': 15,
#    'mild': 15,
#    'lancet': 15,
#    'invasive': 15,
#    'inflammatory': 15,
#    'healthcare': 15,
#    'haldol': 15,
#    'gilbert': 15,
#    'endometriosis': 15,
#    'dizziness': 15,
#    'commonly': 15,
#    'colon': 15,
#    'clothes': 15,
#    'circumcision': 15,
#    'chocolate': 15,
#    'chest': 15,
#    'bee': 15,
#    'antidepressant': 15,
#    'acupuncture': 15,
#    'culture': 47,
#    'mouse': 26,
#    'methodology': 26,
#    'leg': 26,
#    'adult': 26,
#    'blood': 106,
#    'stress': 25,
#    'leaf': 25,
#    'insurance': 25,
#    'helpful': 25,
#    'formation': 25,
#    'viral': 14,
#    'tea': 14,
#    'spelling': 14,
#    'snake': 14,
#    'rutin': 14,
#    'retinal': 14,
#    'resistant': 14,
#    'otc': 14,
#    'osteopathic': 14,
#    'orally': 14,
#    'onset': 14,
#    'occupational': 14,
#    'neurotransmitter': 14,
#    'mcovingt': 14,
#    'intestinal': 14,
#    'hormone': 14,
#    'frequent': 14,
#    'covington': 14,
#    'common': 100,
#    'theory': 95,
#    'condition': 95,
#    'male': 23,
#    'worker': 41,
#    'wax': 13,
#    'urine': 13,
#    'throat': 13,
#    'tablet': 13,
#    'syringe': 13,
#    'supplementation': 13,
#    'sperm': 13,
#    'skull': 13,
#    'recurrent': 13,
#    'psychology': 13,
#    'plate': 13,
#    'patently': 13,
#    'obgyn': 13,
#    'nye': 13,
#    'lactobacillus': 13,
#    'kirilian': 13,
#    'induce': 13,
#    'harmful': 13,
#    'greasy': 13,
#    'fulk': 13,
#    'fortunately': 13,
#    'fiber': 13,
#    'dougb': 13,
#    'disprove': 13,
#    'corona': 13,
#    'scientist': 93,
#    'damage': 40,
#    'weight': 91,
#    'vegetable': 22,
#    'toxic': 22,
#    'iv': 22,
#    'excessive': 22,
#    'doc': 22,
#    'son': 39,
#    'cat': 39,
#    'sleep': 38,
#    'delivery': 38,
#    'wi': 12,
#    'urinary': 12,
#    'testing': 12,
#    'survival': 12,
#    'spray': 12,
#    'spasm': 12,
#    'soup': 12,
#    'sauce': 12,
#    'roth': 12,
#    'quackery': 12,
#    'organ': 12,
#    'obstruction': 12,
#    'nobel': 12,
#    'juice': 12,
#    'insulin': 12,
#    'inhibitor': 12,
#    'immunity': 12,
#    'holland': 12,
#    'heartbeat': 12,
#    'genome': 12,
#    'frighten': 12,
#    'fatal': 12,
#    'enzyme': 12,
#    'efficacy': 12,
#    'dominant': 12,
#    'deposit': 12,
#    'dental': 12,
#    'concentration': 12,
#    'carlton': 12,
#    'antigen': 12,
#    'consume': 21,
#    'charter': 21,
#    'md': 86,
#    'gene': 37,
#    'activity': 37,
#    'bank': 83,
#    'cold': 36,
#    'truth': 20,
#    'transmit': 20,
#    'psychological': 20,
#    'mineral': 20,
#    'kenneth': 20,
#    'injection': 20,
#    'correction': 20,
#    'barrier': 20,
#    'japanese': 35,
#    'injury': 35,
#    'effective': 80,
#    'yellow': 11,
#    'worlds': 11,
#    'vomit': 11,
#    'vmail': 11,
#    'turpin': 11,
#    'tongue': 11,
#    'thumb': 11,
#    'thigh': 11,
#    'sinusitis': 11,
#    'serum': 11,
#    'replicate': 11,
#    'prostate': 11,
#    'pharmacist': 11,
#    'pharmaceutical': 11,
#    'pediatric': 11,
#    'pathogen': 11,
#    'orthopedic': 11,
#    'nutritionist': 11,
#    'jkn': 11,
#    'ip': 11,
#    'ingest': 11,
#    'ineffective': 11,
#    'gourmet': 11,
#    'freds': 11,
#    'effectiveness': 11,
#    'dosage': 11,
#    'crohns': 11,
#    'contraceptive': 11,
#    'complication': 11,
#    'colonization': 11,
#    'colonic': 11,
#    'claire': 11,
#    'chen': 11,
#    'chemotherapy': 11,
#    'carbohydrate': 11,
#    'arthritis': 11,
#    'wrist': 19,
#    'transplant': 19,
#    'rational': 19,
#    'rare': 19,
#    'nurse': 19,
#    'chemistry': 19,
#    'artificial': 19,
#    'baby': 34,
#    'attack': 34,
#    'practice': 77,
#    'mother': 33,
#    'parent': 18,
#    'marty': 18,
#    'flight': 18,
#    'alcohol': 18,
#    'pittsburgh': 32,
#    'drink': 32,
#    'worldwide': 10,
#    'uncontrolled': 10,
#    'tmi': 10,
#    'substantiate': 10,
#    'stimulate': 10,
#    'specialize': 10,
#    'rash': 10,
#    'precaution': 10,
#    'potentially': 10,
#    'philosopher': 10,
#    'phenylalanine': 10,
#    'pharmacy': 10,
#    'pasteur': 10,
#    'ounce': 10,
#    'neurologist': 10,
#    'nasal': 10,
#    'mold': 10,
#    'moisture': 10,
#    'midelfort': 10,
#    'meningitis': 10,
#    'lining': 10,
#    'jealousy': 10,
#    'implicate': 10,
#    'healing': 10,
#    'girlfriend': 10,
#    'extrascientific': 10,
#    'elaine': 10,
#    'eau': 10,
#    'drs': 10,
#    'donor': 10,
#    'daydream': 10,
#    'centipede': 10,
#    'caffeine': 10,
#    'bertrand': 10,
#    'assay': 10,
#    'annals': 10,
#    'absurdity': 10,
#    'energy': 31,
#    'cycle': 31,
#    'data': 70,
#    'brain': 70,
#    'wisdom': 17,
#    'shoulder': 17,
#    'rebound': 17,
#    'prescription': 17,
#    'particle': 17,
#    'gp': 17,
#    'safety': 30,
#    'lady': 30,
#    'experimental': 30,
#    'administration': 30,
#    'age': 67,
#    'population': 29,
#    'victim': 16,
#    'specialist': 16,
#    'shes': 16,
#    'shell': 16,
#    'salt': 16,
#    'provider': 16,
#    'january': 16,
#    'fancy': 16,
#    'examination': 16,
#    'appreciated': 16,
#    'acceptance': 16,
#    'absurd': 16,
#    'wife': 65,
#    'picture': 65,
#    'xuseragent': 9,
#    'wisconsin': 9,
#    'weakness': 9,
#    'warren': 9,
#    'tuberculosis': 9,
#    'trigger': 9,
#    'textbook': 9,
#    'supplier': 9,
#    'specie': 9,
#    'sol': 9,
#    'setup': 9,
#    'receptor': 9,
#    'proponent': 9,
#    'profile': 9,
#    'oz': 9,
#    'organic': 9,
#    'ointment': 9,
#    'nuntius': 9,
#    'nontoxic': 9,
#    'ng': 9,
#    'nervous': 9,
#    'mortality': 9,
#    'metabolism': 9,
#    'metabolic': 9,
#    'merrill': 9,
#    'known': 9,
#    'ivker': 9,
#    'gel': 9,
#    'fatigue': 9,
#    'ent': 9,
#    'elevate': 9,
#    'electric': 9,
#    'diagnostic': 9,
#    'detectable': 9,
#    'controlled': 9,
#    'comfortable': 9,
#    'colleague': 9,
#    'carcinogen': 9,
#    'candidiasis': 9,
#    'calorie': 9,
#    'adverse': 9,
#    'admission': 9,
#    'absence': 9,
#    'visit': 28,
#    'vision': 28,
#    'impossible': 28,
#    'heart': 64,
#    'natural': 63,
#    'sci': 27,
#    'law': 27,
#    'island': 27,
#    'intercourse': 15,
#    'hearing': 15,
#    'hair': 15,
#    'flush': 15,
#    'county': 15,
#    'cone': 15,
#    'alexander': 15,
#    'associate': 61,
#    'hurt': 26,
#    'cook': 26,
#    'cd': 26,
#    'bite': 26,
#    'amateur': 26,
#    'relate': 58,
#    'literature': 58,
#    'zisfein': 8,
#    'vinegar': 8,
#    'underlying': 8,
#    'threshold': 8,
#    'therapeutic': 8,
#    'swallow': 8,
#    'spine': 8,
#    'snort': 8,
#    'sasghm': 8,
#    'rk': 8,
#    'righteye': 8,
#    'rib': 8,
#    'resume': 8,
#    'relaxation': 8,
#    'referral': 8,
#    'rebecca': 8,
#    'potassium': 8,
#    'pneumonia': 8,
#    'petty': 8,
#    'pepper': 8,
#    'overbloom': 8,
#    'ordinary': 8,
#    'misinform': 8,
#    'mackie': 8,
#    'lydick': 8,
#    'lens': 8,
#    'itraconazole': 8,
#    'ingestion': 8,
#    'informationsupplies': 8,
#    'homeopathic': 8,
#    'handedness': 8,
#    'franklin': 8,
#    'favorable': 8,
#    'exam': 8,
#    'doityourselfers': 8,
#    'diabetic': 8,
#    'conception': 8,
#    'colitis': 8,
#    'chromium': 8,
#    'bruise': 8,
#    'bread': 8,
#    'bloodbrain': 8,
#    'benzene': 8,
#    'awareness': 8,
#    'appartus': 8,
#    'anxiety': 8,
#    'adequately': 8,
#    'ache': 8,
#    'tube': 14,
#    'summarize': 14,
#    'sexual': 14,
#    'raw': 14,
#    'poison': 14,
#    'notion': 14,
#    'naturally': 14,
#    'guideline': 14,
#    'discovery': 14,
#    'compound': 14,
#    'brand': 14,
#    'blind': 14,
#    'approximately': 14,
#    'administer': 14,
#    'recommendation': 25,
#    'interview': 25,
#    'sick': 55,
#    'percent': 55,
#    'method': 55,
#    'explanation': 24,
#    'establish': 24,
#    'publish': 54,
#    'wood': 13,
#    'screen': 13,
#    'reliable': 13,
#    'motivation': 13,
#    'manual': 13,
#    'listserv': 13,
#    'irrational': 13,
#    'exceed': 13,
#    'evaluation': 13,
#    'emerge': 13,
#    'elderly': 13,
#    'einstein': 13,
#    'dammit': 13,
#    'vol': 23,
#    'teacher': 23,
#    'negative': 23,
#    'ftp': 23,
#    'detect': 23,
#    'confirm': 23,
#    'procedure': 52,
#    'die': 52,
#    'specific': 51,
#    'family': 51,
#    'worried': 7,
#    'wcsbeau': 7,
#    'vital': 7,
#    'venom': 7,
#    'vaxen': 7,
#    'validate': 7,
#    'unpleasant': 7,
#    'undisputed': 7,
#    'ulcer': 7,
#    'treatable': 7,
#    'todamhyp': 7,
#    'tingle': 7,
#    'therapist': 7,
#    'swollen': 7,
#    'specialty': 7,
#    'skeptic': 7,
#    'secretion': 7,
#    'rude': 7},
#   0.19525,
#   25754.0),
#  ({'orbit': 376,
#    'shuttle': 285,
#    'spacecraft': 229,
#    'solar': 219,
#    'nasa': 322,
#    'launch': 506,
#    'moon': 277,
#    'lunar': 152,
#    'venus': 151,
#    'henry': 150,
#    'sky': 145,
#    'planet': 234,
#    'hst': 115,
#    'orbital': 102,
#    'flight': 174,
#    'burst': 99,
#    'comet': 92,
#    'mar': 161,
#    'payload': 88,
#    'telescope': 86,
#    'jupiter': 86,
#    'titan': 85,
#    'planetary': 82,
#    'kilometer': 80,
#    'propulsion': 78,
#    'orbiter': 78,
#    'billboard': 78,
#    'pluto': 77,
#    'astronaut': 77,
#    'atmosphere': 133,
#    'spencer': 74,
#    'vehicle': 128,
#    'probe': 121,
#    'saturn': 65,
#    'dcx': 64,
#    'exploration': 63,
#    'baalke': 62,
#    'billion': 106,
#    'observatory': 60,
#    'altitude': 60,
#    'radar': 59,
#    'detector': 58,
#    'galileo': 57,
#    'asteroid': 56,
#    'voyager': 54,
#    'antenna': 54,
#    'zoology': 52,
#    'prize': 52,
#    'higgins': 52,
#    'utzoohenry': 50,
#    'ssto': 50,
#    'earth': 356,
#    'fuel': 85,
#    'kg': 47,
#    'temperature': 81,
#    'launcher': 46,
#    'delta': 46,
#    'satellite': 325,
#    'mission': 325,
#    'magellan': 45,
#    'craft': 45,
#    'booster': 45,
#    'astronomer': 45,
#    'proton': 44,
#    'pad': 44,
#    'fred': 44,
#    'cloud': 76,
#    'military': 74,
#    'km': 74,
#    'engine': 74,
#    'nsmca': 42,
#    'mercury': 42,
#    'liquid': 41,
#    'surface': 127,
#    'magnetic': 40,
#    'lander': 40,
#    'thermal': 39,
#    'centaur': 39,
#    'balloon': 38,
#    'aerospace': 38,
#    'sail': 37,
#    'leo': 37,
#    'inflatable': 37,
#    'array': 64,
#    'mass': 114,
#    'meter': 36,
#    'flyby': 36,
#    'crew': 36,
#    'collision': 36,
#    'instrument': 63,
#    'command': 112,
#    'velocity': 35,
#    'trajectory': 35,
#    'timer': 35,
#    'redesign': 35,
#    'pioneer': 35,
#    'mariner': 35,
#    'gif': 60,
#    'reboost': 34,
#    'earths': 34,
#    'atmospheric': 34,
#    'viking': 33,
#    'oxygen': 33,
#    'halo': 33,
#    'ames': 33,
#    'overhead': 32,
#    'funding': 55,
#    'uranus': 31,
#    'ssf': 31,
#    'physicist': 31,
#    'neptune': 31,
#    'gravity': 54,
#    'gamma': 54,
#    'data': 221,
#    'government': 95,
#    'pilot': 30,
#    'pasadena': 30,
#    'landing': 30,
#    'infrared': 30,
#    'hopkins': 30,
#    'dust': 30,
#    'acceleration': 30,
#    'observer': 52,
#    'radiation': 51,
#    'astronomical': 51,
#    'oort': 29,
#    'martian': 29,
#    'belt': 29,
#    'spin': 28,
#    'josh': 28,
#    'highspeed': 28,
#    'gehrels': 28,
#    'venture': 48,
#    'tank': 48,
#    'svr': 48,
#    'shafer': 27,
#    'prb': 27,
#    'moscow': 27,
#    'dryden': 27,
#    'diameter': 27,
#    'boeing': 27,
#    'au': 27,
#    'energy': 85,
#    'module': 47,
#    'activity': 84,
#    'jpl': 46,
#    'gas': 46,
#    'thruster': 26,
#    'ocean': 26,
#    'neutron': 26,
#    'kipling': 26,
#    'crater': 26,
#    'cosmic': 26,
#    'aviation': 26,
#    'ariane': 26,
#    'hardware': 45,
#    'galaxy': 45,
#    'drag': 44,
#    'reston': 25,
#    'pole': 25,
#    'dunn': 25,
#    'atlas': 25,
#    'radius': 43,
#    'spaceflight': 24,
#    'sdio': 24,
#    'jbh': 24,
#    'interstellar': 24,
#    'galactic': 24,
#    'ozone': 42,
#    'rocket': 169,
#    'plane': 41,
#    'advertising': 41,
#    'palmer': 23,
#    'fraering': 23,
#    'bright': 39,
#    'telos': 22,
#    'nasas': 22,
#    'mcdonnell': 22,
#    'gravitational': 22,
#    'celestial': 22,
#    'cassini': 22,
#    'boost': 22,
#    'beam': 22,
#    'soviet': 67,
#    'ground': 67,
#    'apollo': 37,
#    'smiley': 21,
#    'rocketry': 21,
#    'polar': 21,
#    'outer': 21,
#    'oms': 21,
#    'knox': 21,
#    'deg': 21,
#    'contest': 21,
#    'particle': 36,
#    'wrap': 20,
#    'mystery': 20,
#    'clipper': 20,
#    'allen': 63,
#    'station': 144,
#    'pollution': 35,
#    'nuclear': 35,
#    'dennis': 35,
#    'investment': 34,
#    'usaf': 19,
#    'uranium': 19,
#    'technological': 19,
#    'stable': 19,
#    'spectrometer': 19,
#    'reusable': 19,
#    'relay': 19,
#    'pegasus': 19,
#    'optical': 19,
#    'noop': 19,
#    'navigation': 19,
#    'museum': 19,
#    'kjenks': 19,
#    'hydrogen': 19,
#    'esa': 19,
#    'dock': 19,
#    'deploy': 19,
#    'debris': 19,
#    'batse': 19,
#    'image': 136,
#    'distance': 58,
#    'aircraft': 32,
#    'ultraviolet': 18,
#    'telemetry': 18,
#    'spherical': 18,
#    'mir': 18,
#    'mining': 18,
#    'miner': 18,
#    'margin': 18,
#    'dietz': 18,
#    'cosmological': 18,
#    'caterpillar': 18,
#    'burster': 18,
#    'aweto': 18,
#    'arizona': 18,
#    'yamauchi': 17,
#    'tracking': 17,
#    'spare': 17,
#    'mag': 17,
#    'karl': 17,
#    'isotropic': 17,
#    'iron': 17,
#    'interplanetary': 17,
#    'hga': 17,
#    'hannibal': 17,
#    'explorer': 17,
#    'emission': 17,
#    'cruise': 17,
#    'beauty': 17,
#    'alien': 17,
#    'wind': 29,
#    'resemble': 29,
#    'object': 119,
#    'private': 51,
#    'ulysses': 16,
#    'tilt': 16,
#    'sensor': 16,
#    'prototype': 16,
#    'operational': 16,
#    'nicho': 16,
#    'mayan': 16,
#    'jsc': 16,
#    'griffin': 16,
#    'energetic': 16,
#    'dragless': 16,
#    'comprehensive': 16,
#    'coffee': 16,
#    'cm': 16,
#    'churchill': 16,
#    'arc': 16,
#    'tommy': 28,
#    'approximately': 28,
#    'adams': 28,
#    'motion': 50,
#    'pat': 114,
#    'integration': 27,
#    'explore': 27,
#    'bay': 27,
#    'degree': 110,
#    'worden': 15,
#    'televison': 15,
#    'ssrt': 15,
#    'repo': 15,
#    'nearby': 15,
#    'madam': 15,
#    'keithley': 15,
#    'journey': 15,
#    'jenks': 15,
#    'grbs': 15,
#    'gammaray': 15,
#    'er': 15,
#    'digest': 15,
#    'constellation': 15,
#    'chlorine': 15,
#    'charon': 15,
#    'astor': 15,
#    'spectrum': 26,
#    'measurement': 26,
#    'dick': 26,
#    'map': 45,
#    'ftp': 45,
#    'air': 101,
#    'unmanned': 14,
#    'transition': 14,
#    'teflon': 14,
#    'sysmgr': 14,
#    'sunset': 14,
#    'sunrise': 14,
#    'sunlight': 14,
#    'shield': 14,
#    'reentry': 14,
#    'nasajscgm': 14,
#    'mobile': 14,
#    'microwave': 14,
#    'logo': 14,
#    'lb': 14,
#    'kuiper': 14,
#    'hm': 14,
#    'habitable': 14,
#    'gsfc': 14,
#    'ft': 14,
#    'deployment': 14,
#    'constraint': 14,
#    'circular': 14,
#    'atom': 14,
#    'sunos': 24,
#    'signal': 24,
#    'frequency': 24,
#    'disk': 24,
#    'archive': 24,
#    'software': 97,
#    'human': 97,
#    'scale': 42,
#    'remote': 42,
#    'lab': 42,
#    'impact': 42,
#    'land': 95,
#    'mile': 94,
#    'van': 41,
#    'safety': 41,
#    'wk': 13,
#    'vandalism': 13,
#    'steinly': 13,
#    'spinoffs': 13,
#    'respectively': 13,
#    'receiver': 13,
#    'photon': 13,
#    'onboard': 13,
#    'nucleus': 13,
#    'metal': 13,
#    'mcwilliams': 13,
#    'maneuver': 13,
#    'lox': 13,
#    'liftoff': 13,
#    'ir': 13,
#    'icbm': 13,
#    'gregory': 13,
#    'goldin': 13,
#    'flybys': 13,
#    'dense': 13,
#    'degrees': 13,
#    'catalog': 13,
#    'bird': 13,
#    'aiaa': 13,
#    'aeronautics': 13,
#    'aboard': 13,
#    'core': 40,
#    'model': 91,
#    'tm': 22,
#    'simulation': 22,
#    'mineral': 22,
#    'ancient': 22,
#    'visible': 39,
#    'proposal': 38,
#    'mechanism': 38,
#    'wright': 12,
#    'wb': 12,
#    'vacuum': 12,
#    'steinn': 12,
#    'srb': 12,
#    'september': 12,
#    'sand': 12,
#    'ride': 12,
#    'reset': 12,
#    'replacement': 12,
#    'pyron': 12,
#    'peak': 12,
#    'parachute': 12,
#    'onorbit': 12,
#    'maximus': 12,
#    'magnetometer': 12,
#    'lockheed': 12,
#    'krumins': 12,
#    'karla': 12,
#    'italian': 12,
#    'hubble': 12,
#    'hideous': 12,
#    'goddard': 12,
#    'gd': 12,
#    'fraction': 12,
#    'explosive': 12,
#    'explosion': 12,
#    'evolve': 12,
#    'everest': 12,
#    'evas': 12,
#    'energia': 12,
#    'dwarf': 12,
#    'cradle': 12,
#    'cosmos': 12,
#    'continuously': 12,
#    'composition': 12,
#    'clementine': 12,
#    'cargo': 12,
#    'blackbody': 12,
#    'sts': 21,
#    'mount': 21,
#    'fiction': 21,
#    'astronomy': 85,
#    'law': 37,
#    'night': 84,
#    'nick': 36,
#    'nation': 36,
#    'mac': 20,
#    'layer': 20,
#    'electronics': 20,
#    'directory': 20,
#    'observe': 35,
#    'wn': 11,
#    'wm': 11,
#    'voyage': 11,
#    'vandenberg': 11,
#    'tug': 11,
#    'temporary': 11,
#    'teh': 11,
#    'spacewalk': 11,
#    'sigurdsson': 11,
#    'sighting': 11,
#    'scheme': 11,
#    'plastic': 11,
#    'planned': 11,
#    'perihelion': 11,
#    'nicoll': 11,
#    'mid': 11,
#    'manned': 11,
#    'jockey': 11,
#    'jeremy': 11,
#    'huntsville': 11,
#    'gro': 11,
#    'geological': 11,
#    'enzo': 11,
#    'dcy': 11,
#    'combo': 11,
#    'calculator': 11,
#    'astro': 11,
#    'advertiser': 11,
#    'advertisement': 11,
#    'privately': 19,
#    'missile': 19,
#    'freedom': 19,
#    'configuration': 19,
#    'estimate': 34,
#    'water': 33,
#    'vnews': 33,
#    'pound': 33,
#    'newssoftware': 33,
#    'mode': 33,
#    'japan': 33,
#    'vegetable': 18,
#    'transmit': 18,
#    'server': 18,
#    'modify': 18,
#    'investor': 18,
#    'colony': 18,
#    'upper': 32,
#    'heat': 32,
#    'radio': 73,
#    'wierd': 10,
#    'vandalize': 10,
#    'ssmes': 10,
#    'spacelifter': 10,
#    'soyuz': 10,
#    'sherzer': 10,
#    'planning': 10,
#    'perturbation': 10,
#    'nonprofit': 10,
#    'multi': 10,
#    'modular': 10,
#    'milelong': 10,
#    'melbourne': 10,
#    'mcelwaine': 10,
#    'mankind': 10,
#    'liek': 10,
#    'lawson': 10,
#    'lastly': 10,
#    'kilogram': 10,
#    'jettison': 10,
#    'hathaway': 10,
#    'handbook': 10,
#    'grows': 10,
#    'gnb': 10,
#    'gds': 10,
#    'faa': 10,
#    'determination': 10,
#    'decay': 10,
#    'contractor': 10,
#    'contingency': 10,
#    'contamination': 10,
#    'consumables': 10,
#    'constrain': 10,
#    'compton': 10,
#    'collide': 10,
#    'circumference': 10,
#    'bolt': 10,
#    'beautiful': 10,
#    'airliner': 10,
#    'absorb': 10,
#    'abomination': 10,
#    'theory': 72,
#    'mary': 31,
#    'zero': 17,
#    'trash': 17,
#    'transportation': 17,
#    'employee': 17,
#    'discovery': 17,
#    'crystal': 17,
#    'arrive': 17,
#    'stage': 69,
#    'environment': 69,
#    'marketing': 30,
#    'giant': 30,
#    'firm': 30,
#    'dynamic': 30,
#    'universe': 68,
#    'propose': 68,
#    'dc': 67,
#    'century': 29,
#    'bus': 29,
#    'tail': 16,
#    'ruin': 16,
#    'poison': 16,
#    'operator': 16,
#    'max': 16,
#    'houston': 16,
#    'flow': 16,
#    'feasible': 16,
#    'economy': 16,
#    'construction': 16,
#    'civilian': 16,
#    'assembly': 16,
#    'accelerator': 16,
#    'russian': 65,
#    'wavelength': 9,
#    'verne': 9,
#    'thrust': 9,
#    'surveillance': 9,
#    'supernova': 9,
#    'spacerelated': 9,
#    'servicing': 9,
#    'resupply': 9,
#    'readout': 9,
#    'quantum': 9,
#    'qb': 9,
#    'plier': 9,
#    'phobos': 9,
#    'orbiting': 9,
#    'npo': 9,
#    'newsanswersrequest': 9,
#    'nasp': 9,
#    'msfc': 9,
#    'momentum': 9,
#    'meteor': 9,
#    'maneuvering': 9,
#    'lick': 9,
#    'langley': 9,
#    'kelso': 9,
#    'jgreen': 9,
#    'ion': 9,
#    'inclination': 9,
#    'heaven': 9,
#    'geology': 9,
#    'frontier': 9,
#    'feasibility': 9,
#    'equatorial': 9,
#    'downlink': 9,
#    'desert': 9,
#    'dani': 9,
#    'completion': 9,
#    'coegalon': 9,
#    'cheaper': 9,
#    'calibration': 9,
#    'ben': 9,
#    'astrophysics': 9,
#    'aesthetic': 9,
#    'absorption': 9,
#    'vision': 28,
#    'shift': 28,
#    'select': 28,
#    'platform': 28,
#    'cold': 28,
#    'facility': 64,
#    'dr': 64,
#    'transport': 27,
#    'reward': 27,
#    'alive': 27,
#    'tour': 15,
#    'spending': 15,
#    'sector': 15,
#    'prof': 15,
#    'invest': 15,
#    'husband': 15,
#    'foreign': 15,
#    'enterprise': 15,
#    'documentation': 15,
#    'carbon': 15,
#    'atomic': 15,
#    'algorithm': 15,
#    'tax': 26,
#    'resolution': 26,
#    'plant': 26,
#    'panel': 26,
#    'ignore': 26,
#    'gun': 26,
#    'angle': 26,
#    'amateur': 26,
#    'physic': 59,
#    'experiment': 59,
#    'observation': 58,
#    'wire': 8,
#    'vertical': 8,
#    'uv': 8,
#    'transporter': 8,
#    'thirty': 8,
#    'terrestrial': 8,
#    'strap': 8,
#    'startle': 8,
#    'srbs': 8,
#    'spanhepnet': 8,
#    'skylab': 8,
#    'shelf': 8,
#    'sat': 8,
#    'richmond': 8,
#    'rand': 8,
#    'radiator': 8,
#    'publicity': 8,
#    'propellant': 8,
#    'pipe': 8,
#    'periodically': 8,
#    'parity': 8,
#    'originate': 8,
#    'nasda': 8,
#    'microgravity': 8,
#    'lowcost': 8,
#    'llnl': 8,
#    'larrison': 8,
#    'jules': 8,
#    'jovian': 8,
#    'isp': 8,
#    'ira': 8,
#    'hobby': 8,
#    'headquarters': 8,
#    'haines': 8,
#    'guidance': 8,
#    'gradually': 8,
#    'fusion': 8,
#    'fermi': 8,
#    'faint': 8,
#    'eugene': 8,
#    'ether': 8,
#    'ergsec': 8,
#    'edo': 8,
#    'dod': 8,
#    'distant': 8,
#    'davis': 8,
#    'cohen': 8,
#    'closed': 8,
#    'ceo': 8,
#    'ccd': 8,
#    'burdett': 8,
#    'buckeridge': 8,
#    'baube': 8,
#    'awst': 8,
#    'attraction': 8,
#    'astrophysical': 8,
#    'astronautics': 8,
#    'arthur': 8,
#    'anomaly': 8,
#    'annihilation': 8,
#    'angular': 8,
#    'ut': 14,
#    'northern': 14,
#    'livermore': 14,
#    'initiate': 14,
#    'formation': 14,
#    'compose': 14,
#    'calculation': 14,
#    'biological': 14},
#   0.19875,
#   26213.0),
#  ({'stephanopoulos': 325,
#    'homosexual': 261,
#    'government': 697,
#    'abortion': 207,
#    'gay': 197,
#    'fbi': 194,
#    'crime': 155,
#    'koresh': 146,
#    'cramer': 143,
#    'batf': 141,
#    'insurance': 245,
#    'law': 438,
#    'clayton': 130,
#    'drug': 218,
#    'libertarian': 123,
#    'police': 122,
#    'murder': 113,
#    'constitution': 105,
#    'warrant': 103,
#    'kinsey': 103,
#    'tax': 317,
#    'child': 313,
#    'attorney': 99,
#    'health': 305,
#    'officer': 91,
#    'president': 651,
#    'bd': 90,
#    'sexual': 157,
#    'republican': 89,
#    'justice': 88,
#    'consent': 84,
#    'senate': 82,
#    'dee': 82,
#    'reform': 81,
#    'waco': 80,
#    'holocaust': 78,
#    'religion': 77,
#    'court': 135,
#    'davidians': 75,
#    'private': 232,
#    'deficit': 72,
#    'freedom': 124,
#    'liberal': 69,
#    'male': 120,
#    'military': 118,
#    'secretary': 116,
#    'party': 205,
#    'mutual': 65,
#    'kaldis': 64,
#    'vat': 62,
#    'clinton': 195,
#    'uunetpyramidoptilinkcramer': 61,
#    'gun': 190,
#    'witness': 60,
#    'convention': 60,
#    'atf': 60,
#    'amendment': 60,
#    'democracy': 59,
#    'phill': 58,
#    'election': 58,
#    'religious': 101,
#    'homosexuality': 57,
#    'heterosexual': 57,
#    'evil': 57,
#    'criminal': 57,
#    'bush': 57,
#    'stimulus': 54,
#    'reno': 54,
#    'economy': 94,
#    'compound': 94,
#    'conversation': 53,
#    'trial': 93,
#    'survivor': 52,
#    'arrest': 52,
#    'economic': 90,
#    'raid': 51,
#    'promiscuous': 51,
#    'enforcement': 51,
#    'federal': 159,
#    'irrelevant': 50,
#    'church': 50,
#    'security': 49,
#    'cult': 49,
#    'gas': 86,
#    'administration': 146,
#    'labor': 46,
#    'boomer': 46,
#    'sex': 143,
#    'impose': 45,
#    'democratic': 45,
#    'bosnia': 45,
#    'nuclear': 79,
#    'welfare': 44,
#    'assault': 44,
#    'jewish': 43,
#    'commit': 74,
#    'violate': 42,
#    'israel': 42,
#    'campaign': 42,
#    'secret': 73,
#    'jury': 41,
#    'jew': 41,
#    'hallambaker': 41,
#    'billion': 72,
#    'fed': 40,
#    'council': 40,
#    'weapon': 70,
#    'income': 70,
#    'abuse': 70,
#    'discrimination': 39,
#    'constitutional': 39,
#    'senator': 67,
#    'tear': 38,
#    'supreme': 38,
#    'dole': 38,
#    'democrat': 38,
#    'moral': 65,
#    'doctor': 65,
#    'slave': 37,
#    'laughter': 37,
#    'garrett': 37,
#    'conservative': 37,
#    'briefing': 37,
#    'liberty': 36,
#    'iran': 36,
#    'ally': 36,
#    'country': 255,
#    'men': 254,
#    'suicide': 35,
#    'queer': 35,
#    'lord': 35,
#    'edt': 35,
#    'conviction': 35,
#    'population': 110,
#    'enemy': 34,
#    'minority': 105,
#    'socialist': 33,
#    'reagan': 33,
#    'minister': 33,
#    'fuck': 33,
#    'cop': 33,
#    'russia': 103,
#    'nation': 101,
#    'coverage': 100,
#    'ted': 55,
#    'rape': 31,
#    'politician': 31,
#    'plaintiff': 31,
#    'koreshs': 31,
#    'hitler': 31,
#    'violation': 30,
#    'theodore': 30,
#    'premium': 30,
#    'noknock': 30,
#    'mob': 30,
#    'cigarette': 30,
#    'appeal': 30,
#    'war': 214,
#    'house': 211,
#    'citizen': 92,
#    'treatment': 51,
#    'speech': 51,
#    'foreign': 51,
#    'engage': 51,
#    'legislation': 29,
#    'guilty': 29,
#    'follower': 29,
#    'britain': 29,
#    'ground': 90,
#    'regulation': 50,
#    'parent': 50,
#    'investment': 50,
#    'agenda': 50,
#    'social': 89,
#    'teel': 28,
#    'pork': 28,
#    'jefferson': 28,
#    'grenade': 28,
#    'firearm': 28,
#    'affair': 28,
#    'victim': 49,
#    'veto': 27,
#    'tactic': 27,
#    'hostage': 27,
#    'dramatically': 27,
#    'disaster': 27,
#    'cnn': 27,
#    'civil': 85,
#    'activity': 85,
#    'initiative': 47,
#    'political': 190,
#    'spending': 46,
#    'yeltsin': 26,
#    'terrorist': 26,
#    'reich': 26,
#    'provision': 26,
#    'peaceful': 26,
#    'mormon': 26,
#    'governor': 26,
#    'genocide': 26,
#    'compel': 26,
#    'gld': 45,
#    'commitment': 45,
#    'partner': 79,
#    'canadian': 79,
#    'tank': 44,
#    'naval': 44,
#    'thf': 25,
#    'socialism': 25,
#    'sept': 25,
#    'nazi': 25,
#    'gaybi': 25,
#    'exclusively': 25,
#    'bastard': 25,
#    'african': 25,
#    'branch': 78,
#    'peace': 43,
#    'agent': 77,
#    'troop': 24,
#    'territory': 24,
#    'marijuana': 24,
#    'libertarianism': 24,
#    'legislative': 24,
#    'innocent': 24,
#    'hendricks': 24,
#    'enforce': 24,
#    'bomb': 24,
#    'representative': 42,
#    'hospital': 42,
#    'illegal': 74,
#    'human': 169,
#    'sector': 41,
#    'hire': 41,
#    'verdict': 23,
#    'settlement': 23,
#    'propaganda': 23,
#    'median': 23,
#    'involvement': 23,
#    'insurer': 23,
#    'inevitable': 23,
#    'immunization': 23,
#    'hide': 23,
#    'elses': 23,
#    'crisis': 23,
#    'truth': 40,
#    'meeting': 71,
#    'senior': 70,
#    'janet': 39,
#    'govt': 39,
#    'trust': 22,
#    'steveh': 22,
#    'riley': 22,
#    'poverty': 22,
#    'objection': 22,
#    'mitchell': 22,
#    'justification': 22,
#    'gridlock': 22,
#    'fraud': 22,
#    'deviant': 22,
#    'conspiracy': 22,
#    'chamber': 22,
#    'bi': 22,
#    'abolish': 22,
#    'authority': 69,
#    'relationship': 38,
#    'navy': 38,
#    'attack': 68,
#    'vice': 37,
#    'funding': 37,
#    'angeles': 37,
#    'wdstarr': 21,
#    'tenant': 21,
#    'neighborhood': 21,
#    'legally': 21,
#    'legalize': 21,
#    'ignorant': 21,
#    'charity': 21,
#    'adjective': 21,
#    'employee': 36,
#    'package': 146,
#    'kill': 146,
#    'supporter': 20,
#    'statute': 20,
#    'sanction': 20,
#    'pythagorean': 20,
#    'nixon': 20,
#    'nambla': 20,
#    'molestation': 20,
#    'intent': 20,
#    'immoral': 20,
#    'guard': 20,
#    'finance': 20,
#    'cultural': 20,
#    'convict': 20,
#    'bash': 20,
#    'ballot': 20,
#    'allege': 20,
#    'ignore': 63,
#    'evidence': 142,
#    'congress': 141,
#    'argument': 141,
#    'tim': 34,
#    'politics': 34,
#    'leader': 60,
#    'worship': 19,
#    'thug': 19,
#    'selfish': 19,
#    'punishment': 19,
#    'ownership': 19,
#    'neighbor': 19,
#    'morality': 19,
#    'monopoly': 19,
#    'legislature': 19,
#    'housing': 19,
#    'gender': 19,
#    'commerce': 19,
#    'cocaine': 19,
#    'armed': 19,
#    'elect': 33,
#    'deserve': 33,
#    'island': 59,
#    'society': 134,
#    'king': 58,
#    'screw': 32,
#    'revenue': 32,
#    'poll': 32,
#    'voluntary': 18,
#    'soldier': 18,
#    'sexuality': 18,
#    'russotto': 18,
#    'ruling': 18,
#    'prohibit': 18,
#    'prison': 18,
#    'presidential': 18,
#    'lesbian': 18,
#    'herbert': 18,
#    'drieux': 18,
#    'dividians': 18,
#    'conscience': 18,
#    'congressional': 18,
#    'conflict': 18,
#    'closet': 18,
#    'revolution': 31,
#    'policy': 124,
#    'food': 54,
#    'damage': 54,
#    'regardless': 30,
#    'league': 30,
#    'jesus': 30,
#    'gm': 30,
#    'declare': 30,
#    'assertion': 30,
#    'school': 123,
#    'wealthy': 17,
#    'unemployment': 17,
#    'slavery': 17,
#    'provoke': 17,
#    'plague': 17,
#    'parliament': 17,
#    'lsd': 17,
#    'iranian': 17,
#    'cambodia': 17,
#    'bodily': 17,
#    'bible': 17,
#    'energy': 53,
#    'door': 53,
#    'master': 29,
#    'compromise': 29,
#    'brett': 29,
#    'deny': 52,
#    'worthwhile': 16,
#    'wage': 16,
#    'voter': 16,
#    'vast': 16,
#    'ukraine': 16,
#    'starr': 16,
#    'sentence': 16,
#    'riot': 16,
#    'pyotr': 16,
#    'precedent': 16,
#    'politically': 16,
#    'paragraph': 16,
#    'liar': 16,
#    'jeopardy': 16,
#    'jail': 16,
#    'iraq': 16,
#    'invasion': 16,
#    'humanitarian': 16,
#    'hotel': 16,
#    'expression': 16,
#    'employment': 16,
#    'disguise': 16,
#    'dictator': 16,
#    'credibility': 16,
#    'christ': 16,
#    'celebrate': 16,
#    'bust': 16,
#    'authorize': 16,
#    'armenian': 16,
#    'ajteel': 16,
#    'adopt': 16,
#    'salt': 28,
#    'intellectual': 28,
#    'ideal': 28,
#    'girl': 28,
#    'fetus': 28,
#    'false': 28,
#    'circumstance': 28,
#    'birth': 28,
#    'william': 50,
#    'russian': 114,
#    'ensure': 49,
#    'violent': 27,
#    'universal': 27,
#    'inform': 27,
#    'adult': 27,
#    'vested': 15,
#    'uunetiscbrthorsteveh': 15,
#    'transaction': 15,
#    'thorough': 15,
#    'stupidity': 15,
#    'seize': 15,
#    'schnopia': 15,
#    'rutgerskaldis': 15,
#    'regulate': 15,
#    'province': 15,
#    'pot': 15,
#    'ocasey': 15,
#    'negotiate': 15,
#    'missouri': 15,
#    'militia': 15,
#    'legalization': 15,
#    'landlord': 15,
#    'jurisdiction': 15,
#    'julie': 15,
#    'jsh': 15,
#    'invade': 15,
#    'hofferbert': 15,
#    'hennessy': 15,
#    'ethnic': 15,
#    'discriminate': 15,
#    'dealer': 15,
#    'coercion': 15,
#    'bullst': 15,
#    'bombing': 15,
#    'bisexual': 15,
#    'beleive': 15,
#    'barrel': 15,
#    'smoke': 26,
#    'resolve': 26,
#    'penalty': 26,
#    'ought': 26,
#    'christopher': 26,
#    'oil': 46,
#    'georgia': 46,
#    'fear': 45,
#    'weekend': 25,
#    'violence': 25,
#    'union': 25,
#    'steal': 25,
#    'planet': 25,
#    'matt': 25,
#    'cal': 25,
#    'xavier': 14,
#    'warning': 14,
#    'vietnam': 14,
#    'turk': 14,
#    'subsidize': 14,
#    'submarine': 14,
#    'simchik': 14,
#    'shaft': 14,
#    'sacrifice': 14,
#    'reasoning': 14,
#    'radical': 14,
#    'punish': 14,
#    'prostitute': 14,
#    'pretend': 14,
#    'payment': 14,
#    'parade': 14,
#    'neal': 14,
#    'miyazawa': 14,
#    'mandate': 14,
#    'madman': 14,
#    'libertarians': 14,
#    'judgment': 14,
#    'heroin': 14,
#    'elf': 14,
#    'disgust': 14,
#    'deliberately': 14,
#    'delegate': 14,
#    'compliance': 14,
#    'combat': 14,
#    'carter': 14,
#    'bullshit': 14,
#    'proof': 44,
#    'truck': 24,
#    'santa': 24,
#    'republic': 24,
#    'loan': 24,
#    'lawyer': 24,
#    'dennis': 24,
#    'debt': 24,
#    'christian': 24,
#    'threat': 43,
#    'atlantic': 43,
#    'agreement': 43,
#    'education': 97,
#    'mass': 42,
#    'property': 96,
#    'land': 96,
#    'virginia': 23,
#    'massive': 23,
#    'civilian': 23,
#    'accuse': 23,
#    'orientation': 41,
#    'debate': 41,
#    'wiretapping': 13,
#    'veal': 13,
#    'thereof': 13,
#    'spy': 13,
#    'serb': 13,
#    'selective': 13,
#    'rosa': 13,
#    'rodney': 13,
#    'relativity': 13,
#    'racial': 13,
#    'quayle': 13,
#    'prettier': 13,
#    'pressdemocrat': 13,
#    'prejudice': 13,
#    'pedophile': 13,
#    'paraphrase': 13,
#    'occupation': 13,
#    'muslim': 13,
#    'molester': 13,
#    'molest': 13,
#    'lobby': 13,
#    'lethal': 13,
#    'kriz': 13,
#    'interpretation': 13,
#    'ideology': 13,
#    'freivald': 13,
#    'foolish': 13,
#    'fascist': 13,
#    'failed': 13,
#    'extermination': 13,
#    'eh': 13,
#    'dzkriz': 13,
#    'davidian': 13,
#    'contradict': 13,
#    'contend': 13,
#    'communist': 13,
#    'bullet': 13,
#    'borrow': 13,
#    'bearing': 13,
#    'arab': 13,
#    'appoint': 13,
#    'allegation': 13,
#    'advisor': 13,
#    'history': 93,
#    'establish': 40,
#    'blame': 40,
#    'yesterday': 91,
#    'vote': 91,
#    'kid': 91,
#    'taxpayer': 22,
#    'female': 22,
#    'economics': 22,
#    'corrupt': 22,
#    'burden': 22,
#    'alcohol': 22,
#    'water': 39,
#    'german': 39,
#    'destroy': 39,
#    'cite': 39,
#    'town': 38,
#    'mother': 38,
#    'director': 38,
#    'advocate': 38,
#    'writing': 12,
#    'waldrop': 12,
#    'tragic': 12,
#    'tragedy': 12,
#    'toilet': 12,
#    'tenn': 12,
#    'sudden': 12,
#    'secure': 12,
#    'ruler': 12,
#    'retreat': 12,
#    'regime': 12,
#    'provincial': 12,
#    'prochoice': 12,
#    'perot': 12,
#    'paranoid': 12,
#    'negotiation': 12,
#    'natonal': 12,
#    'mechalas': 12,
#    'mccarthy': 12,
#    'marine': 12,
#    'margolis': 12,
#    'legality': 12,
#    'killing': 12,
#    'israeli': 12,
#    'irresponsible': 12,
#    'humor': 12,
#    'genuine': 12,
#    'frustrate': 12,
#    'federally': 12,
#    'explicitly': 12,
#    'elevator': 12,
#    'effectively': 12,
#    'doorbell': 12,
#    'domestic': 12,
#    'disregard': 12,
#    'deliberate': 12,
#    'dawn': 12,
#    'contradictory': 12,
#    'cont': 12,
#    'comply': 12,
#    'comedy': 12,
#    'capitalist': 12,
#    'borden': 12,
#    'bonus': 12,
#    'aj': 12,
#    'vehicle': 21,
#    'trend': 21,
#    'roman': 21,
#    'historical': 21,
#    'draft': 21,
#    'bell': 21,
#    'assert': 21,
#    'practice': 86,
#    'specific': 85,
#    'responsibility': 85,
#    'risk': 37,
#    'america': 84,
#    'strongly': 36,
#    'plant': 36,
#    'manner': 36,
#    'hardly': 36,
#    'culture': 36,
#    'shit': 20,
#    'non': 20,
#    'hearing': 20,
#    'contrary': 20,
#    'consumer': 20,
#    'collapse': 20,
#    'broad': 20,
#    'morning': 82,
#    'data': 82,
#    'aid': 82,
#    'protection': 35,
#    'incident': 35,
#    'immediate': 35,
#    'dare': 35,
#    'advice': 35,
#    'legal': 80,
#    'zionist': 11,
#    'whatsoever': 11,
#    'utopian': 11,
#    'unprovoked': 11,
#    'unfair': 11,
#    'uh': 11,
#    'tyranny': 11,
#    'truely': 11,
#    'summit': 11,
#    'succeed': 11,
#    'sincerely': 11,
#    'siege': 11,
#    'scary': 11,
#    'rescue': 11,
#    'refusal': 11,
#    'rant': 11,
#    'promiscuity': 11,
#    'proclaim': 11,
#    'prepared': 11,
#    'preference': 11,
#    'outcome': 11,
#    'occupant': 11,
#    'obey': 11,
#    'mow': 11,
#    'kolodny': 11,
#    'jerusalem': 11,
#    'irs': 11,
#    'instability': 11,
#    'inhabitant': 11,
#    'horrible': 11,
#    'honestly': 11,
#    'hmo': 11,
#    'hatred': 11,
#    'hallam': 11,
#    'framework': 11,
#    'fascism': 11,
#    'embassy': 11,
#    'disproportionate': 11,
#    'deter': 11,
#    'declaration': 11,
#    'coverup': 11,
#    'condemn': 11,
#    'cma': 11},
#   0.20475,
#   33454.0)]

# %%
joblib.dump(lookup_table_80_20,"lookup_table_80_20_k_700")
# Out:
# ['lookup_table_80_20_k_700']

# %%
len(lookup_table_80_20[1][0].keys())
# Out:
# 700

# %%
def test_naive_bayes(sentence, lookup_table):
    likelihood = np.zeros(len(unique_classes))
    words = [str(word) for word in sentence.split(" ")]
    for label_index,index in enumerate(unique_classes):
        for word in words:
            # likelihood = count(word)+1 / vocab + word_counts_in_class
            likelihood[label_index] += np.log((lookup_table[label_index][0].get(word,0)+1) /(float(lookup_table[label_index][2])))
    posterior = np.empty(len(unique_classes))
    for label_index,label in enumerate(unique_classes):
        posterior[label_index] = np.log(lookup_table[label_index][1])+ likelihood[label_index]
    return unique_classes[np.argmax(posterior)]

# %%
unique_classes=list(set(train_80_20['label'].values))

# %%
test_80_20['text'] = test_80_20['text'].astype(str)

# %%
predictions = test_80_20['text'].apply(lambda x: test_naive_bayes(x, lookup_table_80_20))

# %%
predictions.values
# Out:
# array([2, 0, 4, 4, 4, 1, 1, 0, 3, 3, 3, 2, 2, 3, 2, 0, 0, 2, 2, 1, 1, 4,
#        2, 4, 2, 0, 1, 1, 1, 0, 0, 1, 0, 1, 2, 3, 1, 3, 0, 4, 1, 2, 3, 4,
#        0, 2, 2, 2, 4, 4, 3, 1, 3, 3, 4, 0, 2, 0, 1, 3, 4, 2, 2, 0, 4, 2,
#        3, 2, 2, 0, 4, 3, 2, 2, 4, 2, 3, 4, 2, 4, 2, 0, 1, 1, 0, 3, 1, 1,
#        2, 3, 1, 1, 2, 3, 2, 1, 0, 4, 3, 4, 3, 4, 4, 2, 3, 1, 1, 3, 2, 2,
#        0, 0, 1, 2, 4, 1, 4, 0, 1, 2, 0, 3, 1, 3, 4, 0, 4, 1, 0, 4, 2, 3,
#        2, 0, 1, 4, 1, 2, 3, 3, 0, 3, 3, 4, 2, 1, 0, 1, 3, 4, 3, 4, 1, 1,
#        1, 1, 1, 4, 4, 2, 0, 0, 0, 2, 4, 1, 0, 3, 4, 3, 1, 0, 3, 4, 1, 3,
#        4, 4, 0, 0, 4, 1, 1, 4, 4, 0, 2, 3, 2, 3, 3, 2, 4, 2, 3, 0, 1, 1,
#        3, 3, 0, 2, 4, 4, 3, 1, 4, 0, 1, 1, 2, 2, 0, 0, 2, 0, 2, 3, 0, 2,
#        4, 0, 1, 3, 1, 0, 3, 2, 4, 3, 3, 0, 2, 2, 2, 2, 2, 2, 0, 0, 4, 2,
#        4, 1, 3, 4, 4, 3, 1, 2, 2, 4, 4, 3, 3, 4, 2, 1, 3, 1, 2, 1, 4, 4,
#        4, 2, 0, 4, 4, 2, 2, 3, 1, 1, 0, 0, 3, 2, 0, 0, 2, 3, 0, 1, 2, 3,
#        3, 0, 2, 0, 2, 2, 0, 2, 4, 3, 1, 1, 4, 4, 2, 2, 0, 1, 4, 3, 1, 3,
#        4, 4, 2, 1, 1, 1, 2, 1, 0, 2, 3, 2, 4, 2, 2, 1, 0, 4, 3, 2, 3, 3,
#        3, 0, 2, 3, 1, 2, 0, 3, 4, 0, 0, 1, 3, 3, 3, 2, 1, 2, 2, 2, 3, 2,
#        0, 2, 3, 1, 3, 1, 1, 2, 3, 4, 2, 4, 2, 3, 0, 2, 2, 0, 2, 3, 3, 3,
#        3, 1, 1, 3, 4, 2, 0, 4, 1, 2, 1, 2, 0, 1, 1, 3, 0, 2, 3, 0, 4, 2,
#        4, 3, 4, 4, 2, 3, 1, 1, 1, 4, 2, 4, 0, 2, 4, 1, 2, 1, 2, 3, 0, 1,
#        0, 4, 1, 2, 2, 3, 3, 0, 0, 0, 3, 3, 2, 4, 3, 1, 1, 4, 2, 2, 2, 4,
#        0, 1, 0, 2, 3, 3, 0, 1, 0, 2, 3, 3, 0, 0, 0, 0, 3, 0, 1, 3, 4, 3,
#        2, 0, 0, 1, 3, 0, 2, 3, 1, 2, 4, 2, 4, 0, 3, 2, 0, 0, 3, 1, 0, 2,
#        4, 3, 0, 3, 0, 2, 2, 2, 3, 3, 4, 1, 4, 4, 2, 1, 1, 3, 3, 1, 0, 0,
#        1, 3, 2, 4, 2, 0, 0, 4, 2, 0, 0, 1, 2, 2, 2, 4, 2, 1, 2, 1, 4, 3,
#        0, 0, 1, 3, 3, 1, 3, 3, 4, 2, 3, 1, 1, 0, 2, 3, 3, 0, 1, 2, 2, 4,
#        3, 0, 2, 3, 2, 2, 0, 1, 3, 0, 0, 0, 4, 2, 0, 0, 0, 1, 3, 0, 1, 2,
#        1, 2, 2, 0, 0, 4, 2, 1, 0, 2, 2, 2, 0, 4, 3, 2, 1, 2, 3, 3, 2, 1,
#        4, 3, 3, 2, 0, 3, 1, 0, 3, 4, 3, 3, 0, 3, 1, 0, 0, 1, 2, 3, 2, 4,
#        0, 0, 4, 2, 0, 1, 2, 3, 0, 0, 4, 3, 0, 2, 2, 3, 2, 1, 0, 4, 3, 0,
#        3, 0, 3, 2, 1, 0, 4, 3, 2, 1, 2, 1, 2, 1, 3, 4, 1, 0, 3, 1, 1, 2,
#        2, 4, 4, 3, 4, 3, 4, 1, 4, 3, 1, 1, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3,
#        1, 0, 0, 1, 2, 1, 1, 3, 1, 4, 2, 0, 4, 2, 2, 3, 3, 2, 0, 3, 4, 0,
#        4, 2, 3, 2, 2, 2, 1, 2, 3, 0, 1, 0, 2, 0, 2, 0, 2, 2, 1, 4, 0, 2,
#        3, 3, 2, 0, 4, 4, 2, 1, 3, 2, 4, 0, 3, 0, 4, 0, 2, 0, 0, 2, 0, 4,
#        0, 2, 4, 0, 0, 4, 4, 2, 2, 0, 0, 1, 1, 1, 3, 4, 2, 0, 3, 0, 3, 2,
#        1, 4, 0, 4, 1, 2, 1, 1, 0, 2, 2, 4, 2, 3, 3, 2, 0, 2, 0, 4, 1, 0,
#        4, 2, 3, 2, 2, 2, 1, 3, 3, 2, 3, 2, 4, 4, 3, 2, 3, 4, 1, 4, 1, 1,
#        1, 1, 3, 1, 2, 1, 4, 4, 1, 4, 2, 4, 2, 0, 3, 1, 0, 2, 2, 2, 3, 0,
#        0, 4, 1, 0, 0, 2, 3, 3, 2, 2, 3, 2, 1, 2, 2, 3, 3, 4, 3, 2, 1, 3,
#        2, 2, 4, 0, 2, 0, 3, 2, 4, 3, 1, 2, 4, 4, 3, 0, 3, 4, 3, 4, 2, 4,
#        0, 1, 2, 0, 3, 2, 3, 3, 2, 1, 0, 2, 1, 1, 1, 2, 0, 1, 0, 0, 3, 0,
#        3, 4, 3, 1, 1, 1, 2, 4, 0, 3, 0, 0, 1, 1, 1, 3, 4, 1, 2, 2, 1, 0,
#        3, 3, 2, 2, 2, 3, 1, 2, 1, 0, 2, 2, 2, 2, 3, 0, 1, 2, 3, 1, 3, 2,
#        2, 4, 1, 0, 2, 1, 3, 3, 3, 2, 1, 2, 4, 2, 3, 2, 3, 2, 0, 3, 3, 2,
#        3, 1, 3, 0, 1, 4, 4, 4, 1, 2, 4, 1, 2, 4, 3, 0, 2, 0, 0, 0, 3, 2,
#        2, 3, 4, 1, 1, 4, 1, 2, 1, 2])

# %%
test_labels = LE.transform(test_80_20['label'].values)
test_labels
# Out:
# array([2, 0, 4, 4, 1, 1, 1, 0, 0, 0, 3, 2, 0, 3, 0, 0, 0, 2, 2, 1, 1, 4,
#        2, 4, 2, 4, 1, 1, 1, 0, 0, 1, 0, 1, 2, 3, 1, 3, 0, 4, 1, 2, 4, 4,
#        0, 2, 4, 2, 4, 4, 3, 1, 3, 3, 4, 0, 2, 0, 1, 3, 4, 2, 2, 0, 4, 2,
#        3, 4, 2, 0, 4, 3, 2, 2, 4, 2, 3, 4, 2, 4, 2, 0, 1, 1, 0, 3, 1, 1,
#        2, 3, 1, 1, 2, 3, 2, 1, 0, 4, 3, 4, 4, 4, 4, 2, 3, 1, 2, 3, 2, 2,
#        0, 0, 1, 3, 4, 1, 4, 0, 1, 4, 3, 3, 1, 3, 4, 0, 4, 1, 0, 4, 2, 2,
#        4, 0, 1, 4, 1, 2, 3, 3, 0, 3, 3, 4, 2, 1, 0, 1, 1, 4, 3, 4, 1, 1,
#        1, 1, 1, 4, 4, 2, 0, 0, 0, 2, 4, 1, 0, 3, 4, 0, 1, 0, 3, 4, 1, 3,
#        4, 4, 0, 2, 4, 1, 1, 4, 4, 0, 2, 3, 2, 3, 3, 4, 4, 2, 3, 0, 1, 1,
#        3, 3, 0, 2, 4, 4, 3, 1, 4, 0, 1, 1, 2, 1, 0, 1, 2, 0, 2, 3, 0, 2,
#        4, 0, 1, 3, 1, 0, 3, 2, 4, 1, 3, 2, 2, 2, 2, 2, 2, 2, 0, 0, 4, 2,
#        4, 1, 2, 4, 4, 3, 1, 0, 2, 4, 4, 3, 3, 4, 2, 1, 3, 1, 2, 1, 4, 4,
#        4, 0, 0, 4, 4, 1, 2, 3, 1, 1, 0, 0, 3, 2, 4, 0, 2, 3, 0, 1, 2, 3,
#        3, 0, 3, 0, 2, 2, 0, 2, 4, 0, 1, 1, 4, 4, 2, 2, 0, 1, 4, 3, 1, 3,
#        4, 4, 2, 1, 1, 1, 2, 1, 0, 2, 3, 2, 4, 2, 2, 1, 0, 4, 3, 2, 3, 3,
#        3, 0, 2, 3, 1, 2, 0, 3, 4, 0, 0, 1, 3, 3, 3, 4, 1, 2, 2, 4, 3, 3,
#        0, 2, 3, 1, 2, 1, 1, 2, 3, 4, 4, 4, 2, 3, 0, 2, 3, 0, 2, 3, 3, 3,
#        3, 1, 1, 3, 4, 2, 0, 4, 1, 2, 1, 2, 0, 1, 1, 4, 0, 2, 3, 0, 4, 2,
#        4, 3, 4, 4, 2, 3, 1, 1, 4, 4, 3, 4, 3, 2, 4, 1, 1, 1, 2, 3, 0, 1,
#        0, 4, 1, 2, 4, 3, 3, 0, 0, 0, 3, 3, 2, 4, 3, 1, 1, 4, 2, 4, 0, 4,
#        0, 1, 0, 2, 3, 3, 0, 1, 0, 2, 3, 3, 0, 0, 0, 0, 3, 0, 1, 3, 4, 3,
#        2, 0, 0, 1, 2, 0, 2, 3, 1, 0, 4, 2, 4, 0, 3, 2, 0, 0, 3, 1, 0, 2,
#        4, 3, 2, 3, 0, 2, 2, 2, 3, 3, 4, 1, 4, 4, 2, 1, 1, 3, 3, 1, 0, 0,
#        1, 3, 2, 4, 2, 0, 0, 4, 2, 0, 0, 1, 2, 2, 2, 2, 2, 1, 2, 1, 4, 3,
#        0, 0, 1, 3, 3, 1, 3, 3, 4, 2, 3, 1, 1, 0, 2, 3, 3, 0, 1, 2, 2, 4,
#        3, 3, 2, 3, 3, 2, 0, 1, 3, 0, 0, 0, 4, 2, 0, 0, 0, 1, 3, 0, 1, 2,
#        1, 2, 4, 0, 0, 4, 2, 1, 0, 2, 3, 2, 0, 4, 3, 2, 1, 2, 3, 3, 2, 1,
#        4, 3, 3, 2, 3, 3, 1, 0, 3, 4, 3, 3, 3, 3, 1, 0, 0, 1, 4, 3, 2, 3,
#        0, 0, 4, 2, 0, 1, 2, 3, 0, 0, 4, 0, 0, 2, 4, 3, 2, 1, 0, 4, 3, 0,
#        3, 0, 3, 2, 1, 0, 4, 3, 2, 1, 2, 1, 2, 1, 3, 4, 1, 0, 3, 1, 1, 2,
#        2, 4, 4, 3, 4, 2, 4, 1, 4, 3, 1, 1, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3,
#        1, 3, 0, 1, 4, 1, 1, 3, 1, 4, 4, 0, 4, 2, 2, 3, 3, 2, 0, 3, 4, 0,
#        4, 4, 3, 2, 2, 2, 1, 2, 3, 0, 1, 0, 2, 0, 2, 0, 2, 2, 1, 4, 0, 2,
#        3, 3, 2, 0, 4, 4, 2, 1, 3, 2, 4, 0, 3, 0, 4, 0, 2, 0, 0, 2, 0, 4,
#        0, 2, 4, 0, 0, 4, 4, 0, 2, 0, 0, 1, 1, 1, 3, 4, 2, 0, 3, 0, 3, 2,
#        1, 4, 0, 4, 1, 2, 1, 1, 0, 2, 3, 4, 3, 3, 3, 2, 0, 0, 0, 4, 1, 0,
#        4, 3, 3, 2, 2, 2, 1, 3, 3, 0, 3, 2, 4, 4, 3, 2, 3, 4, 1, 4, 1, 1,
#        1, 1, 3, 1, 2, 1, 4, 4, 1, 4, 0, 4, 2, 0, 3, 1, 0, 2, 2, 1, 3, 0,
#        4, 4, 1, 2, 0, 2, 3, 3, 2, 2, 3, 2, 1, 2, 2, 3, 3, 4, 2, 2, 1, 3,
#        2, 2, 4, 0, 4, 0, 3, 2, 4, 3, 1, 2, 4, 4, 3, 0, 4, 4, 3, 4, 2, 4,
#        0, 1, 2, 0, 3, 2, 3, 3, 2, 1, 0, 3, 1, 1, 1, 2, 0, 1, 0, 0, 3, 0,
#        3, 2, 0, 1, 1, 1, 3, 4, 0, 3, 0, 0, 1, 1, 1, 4, 4, 1, 2, 2, 1, 0,
#        3, 3, 1, 2, 2, 3, 1, 2, 1, 0, 2, 3, 2, 2, 3, 0, 1, 2, 3, 1, 3, 2,
#        2, 4, 1, 0, 2, 1, 0, 3, 3, 2, 1, 2, 4, 2, 0, 3, 3, 2, 0, 3, 3, 2,
#        2, 1, 3, 0, 1, 4, 4, 4, 1, 2, 4, 1, 2, 4, 3, 0, 1, 0, 0, 0, 3, 2,
#        2, 3, 4, 1, 1, 4, 1, 2, 1, 2])

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(test_labels,predictions.values, average='macro')
# Out:
# (0.919821108923119, 0.9097029913321819, 0.9130323766884143, None)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.911

# %%
def accuracy_per_class(preds_flat, labels_flat):

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {LE.inverse_transform([label])}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 181/195
#
# Class: ['rec.sport.hockey']
# Accuracy: 186/188
#
# Class: ['sci.med']
# Accuracy: 205/252
#
# Class: ['sci.space']
# Accuracy: 184/206
#
# Class: ['talk.politics.misc']
# Accuracy: 155/159

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %%
# 80 20

bag_of_wrds_70_30 = joblib.load("selected_features_70_30_k_700")
train_70_30 = pd.read_csv("train_70_30_split.csv")
test_70_30 = pd.read_csv("test_70_30_split.csv")
LE = preprocessing.LabelEncoder()
train_70_30['label'] = LE.fit_transform(train_70_30['label'].values)
lookup_table_70_30 = train_naive_bayes(train_70_30['label'].values, list(set(train_70_30['label'].values)), bag_of_wrds_70_30)

# %%
joblib.dump(lookup_table_70_30,'lookup_table_70_30_700')
# Out:
# ['lookup_table_70_30_700']

# %%
test_70_30['text'] = test_70_30['text'].astype(str)

# %%
set(test_70_30['label'].values)
# Out:
# {'comp.graphics',
#  'rec.sport.hockey',
#  'sci.med',
#  'sci.space',
#  'talk.politics.misc'}

# %%
predictions = test_70_30['text'].apply(lambda x: test_naive_bayes(x, lookup_table_70_30))

# %%
test_labels = LE.transform(test_70_30['label'].values)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.9073333333333333

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 265/284
#
# Class: ['rec.sport.hockey']
# Accuracy: 283/291
#
# Class: ['sci.med']
# Accuracy: 282/369
#
# Class: ['sci.space']
# Accuracy: 251/268
#
# Class: ['talk.politics.misc']
# Accuracy: 280/288

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %%
# 80 20

bag_of_wrds_50_50 = joblib.load("selected_features_50_50_k_700")
train_50_50 = pd.read_csv("train_50_50_split.csv")
test_50_50 = pd.read_csv("test_50_50_split.csv")
LE = preprocessing.LabelEncoder()
train_50_50['label'] = LE.fit_transform(train_50_50['label'].values)
lookup_table_50_50 = train_naive_bayes(train_50_50['label'].values, list(set(train_50_50['label'].values)), bag_of_wrds_50_50)

# %%
test_50_50['text'] = test_50_50['text'].astype(str)

# %%
set(test_50_50['label'].values)
# Out:
# {'comp.graphics',
#  'rec.sport.hockey',
#  'sci.med',
#  'sci.space',
#  'talk.politics.misc'}

# %%
predictions = test_50_50['text'].apply(lambda x: test_naive_bayes(x, lookup_table_50_50))

# %%
test_labels = LE.transform(test_50_50['label'].values)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.8728

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 409/429
#
# Class: ['rec.sport.hockey']
# Accuracy: 456/461
#
# Class: ['sci.med']
# Accuracy: 509/656
#
# Class: ['sci.space']
# Accuracy: 466/604
#
# Class: ['talk.politics.misc']
# Accuracy: 342/350

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app
