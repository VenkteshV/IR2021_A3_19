# %%
import pandas as pd
import numpy as np

import joblib
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
def train_naive_bayes(labels,unique_classes, bag_of_words):   

    prior_prob = np.empty(len(labels))
    vocab = []
    words_in_label = np.empty(len(labels))
    for label_index,label in enumerate(unique_classes):
        prior_prob[label_index] = np.sum(labels == label) / float(len(labels))
        words_in_label[label_index]=np.sum(np.array(list(bag_of_words[label_index].values())))
        vocab += bag_of_words[label_index].keys()
    vocab = np.unique(np.array(vocab))
    likelihood_dividor = np.array([words_in_label[label_index]+len(vocab) for label_index, label in enumerate(unique_classes)])
    lookup_table =[]
    for label_index, label in enumerate(unique_classes):
        lookup_table.append((bag_of_words[label_index],prior_prob[label_index],likelihood_dividor[label_index]))
    return lookup_table

# %%
# 80 20

bag_of_wrds_80_20 = joblib.load("selected_features_80_20")
train_80_20 = pd.read_csv("train_80_20_split.csv")
test_80_20 = pd.read_csv("test_80_20_split.csv")
LE = preprocessing.LabelEncoder()
train_80_20['label'] = LE.fit_transform(train_80_20['label'].values)
lookup_table_80_20 = train_naive_bayes(train_80_20['label'].values, list(set(train_80_20['label'].values)), bag_of_wrds_80_20)

# %%
lookup_table_80_20
# Out:
# [({'jpeg': 673,
#    'graphic': 538,
#    'image': 1562,
#    'gif': 331,
#    'pixel': 151,
#    'tiff': 132,
#    'polygon': 129,
#    'xv': 112,
#    'animation': 111,
#    'conversion': 110,
#    'output': 104,
#    'shareware': 101,
#    'viewer': 175,
#    'quicktime': 94,
#    'amiga': 92,
#    'sgi': 88,
#    'mac': 153,
#    'directory': 153,
#    'interface': 84,
#    'compression': 82,
#    'ftp': 254,
#    'postscript': 79,
#    'zip': 78,
#    'workstation': 78,
#    'vesa': 78,
#    'visualization': 77,
#    'format': 542,
#    'algorithm': 130,
#    'screen': 126,
#    'driver': 126,
#    'gopher': 71,
#    'vga': 70,
#    'simtel': 69,
#    'archive': 117,
#    'hardware': 116,
#    'rayshade': 66,
#    'phigs': 66,
#    'server': 115,
#    'hacker': 64,
#    'compress': 63,
#    'colour': 110,
#    'quantization': 62,
#    'color': 440,
#    'siggraph': 59,
#    'menu': 59,
#    'filter': 58,
#    'tracer': 57,
#    'interactive': 57,
#    'software': 408,
#    'gifs': 56,
#    'texture': 55,
#    'byte': 55,
#    'version': 389,
#    'pc': 167,
#    'vertex': 51,
#    'card': 160,
#    'macintosh': 50,
#    'cview': 50,
#    'buffer': 50,
#    'archie': 50,
#    'display': 357,
#    'rgb': 49,
#    'converter': 49,
#    'render': 86,
#    'database': 86,
#    'data': 353,
#    'scene': 48,
#    'library': 151,
#    'host': 47,
#    'arithmetic': 46,
#    'utility': 80,
#    'smooth': 45,
#    'dec': 45,
#    'xloadimage': 44,
#    'virtual': 44,
#    'transformation': 44,
#    'photoshop': 44,
#    'frame': 77,
#    'processing': 138,
#    'adobe': 43,
#    'raster': 42,
#    'toolkit': 41,
#    'pov': 41,
#    'lossless': 41,
#    'manipulation': 72,
#    'disk': 71,
#    'processor': 40,
#    'mode': 124,
#    'package': 283,
#    'printer': 39,
#    'demo': 39,
#    'meg': 38,
#    'implementation': 36,
#    'input': 62,
#    'svga': 35,
#    'radiosity': 35,
#    'grayscale': 35,
#    'client': 61,
#    'windows': 34,
#    'ppm': 34,
#    'nfotis': 34,
#    'listing': 34,
#    'linear': 34,
#    'cad': 34,
#    'bitmap': 34,
#    'gamma': 59,
#    'palette': 33,
#    'motif': 33,
#    'code': 237,
#    'convert': 233,
#    'vector': 32,
#    'targa': 32,
#    'msdos': 31,
#    'geometry': 31,
#    'convex': 31,
#    'unix': 97,
#    'plane': 54,
#    'compile': 53,
#    'art': 53,
#    'rle': 30,
#    'pd': 30,
#    'mhz': 30,
#    'linux': 30,
#    'intersection': 30,
#    'fractal': 30,
#    'compatible': 30,
#    'cod': 30,
#    'clip': 30,
#    'arbitrary': 30,
#    'surface': 94,
#    'pub': 29,
#    'ch': 29,
#    'map': 91,
#    'plot': 89,
#    'wireframe': 28,
#    'programming': 28,
#    'lightwave': 28,
#    'fps': 28,
#    'font': 28,
#    'enhancement': 28,
#    'setting': 48,
#    'xx': 27,
#    'spec': 27,
#    'mirror': 83,
#    'xli': 26,
#    'widget': 26,
#    'renderer': 26,
#    'raytracing': 26,
#    'manchester': 26,
#    'geometric': 26,
#    'dither': 26,
#    'abstract': 26,
#    'hp': 45,
#    'object': 184,
#    'routine': 80,
#    'ibm': 79,
#    'manual': 44,
#    'extension': 44,
#    'xyz': 25,
#    'temp': 25,
#    'storage': 25,
#    'pict': 25,
#    'pbmplus': 25,
#    'manipulate': 25,
#    'intensity': 25,
#    'fortran': 25,
#    'download': 25,
#    'digitize': 25,
#    'ascii': 25,
#    'window': 179,
#    'ultra': 24,
#    'silicon': 24,
#    'selection': 24,
#    'scanner': 24,
#    'jpegs': 24,
#    'iris': 24,
#    'hicolor': 24,
#    'gl': 24,
#    'contour': 24,
#    'cclilley': 24,
#    'ati': 24,
#    'documentation': 42,
#    'quality': 170,
#    'sphere': 41,
#    'xwindows': 23,
#    'intersect': 23,
#    'cjpeg': 23,
#    'platform': 72,
#    'quadra': 22,
#    'proprietary': 22,
#    'povray': 22,
#    'portable': 22,
#    'log': 22,
#    'functionality': 22,
#    'dxf': 22,
#    'tool': 158,
#    'video': 157,
#    'fax': 157,
#    'module': 38,
#    'binary': 38,
#    'digital': 67,
#    'mb': 37,
#    'workshop': 21,
#    'vi': 21,
#    'transform': 21,
#    'tga': 21,
#    'modification': 21,
#    'modeling': 21,
#    'alpha': 21,
#    'signal': 36,
#    'default': 36,
#    'readme': 20,
#    'iff': 20,
#    'floppy': 20,
#    'ellipse': 20,
#    'corel': 20,
#    'bmp': 20,
#    'algorithms': 20,
#    'acm': 20,
#    'application': 144,
#    'shade': 35,
#    'online': 61,
#    'telnet': 19,
#    'subroutine': 19,
#    'spline': 19,
#    'quantize': 19,
#    'pex': 19,
#    'patch': 19,
#    'pascal': 19,
#    'modem': 19,
#    'jpg': 19,
#    'graeme': 19,
#    'filename': 19,
#    'import': 32,
#    'width': 18,
#    'tag': 18,
#    'sumex': 18,
#    'pic': 18,
#    'password': 18,
#    'histogram': 18,
#    'graphical': 18,
#    'drawing': 18,
#    'cpu': 18,
#    'alchemy': 18,
#    'ab': 18,
#    'dos': 31,
#    'ray': 126,
#    'model': 123,
#    'zoom': 17,
#    'variable': 17,
#    'tmc': 17,
#    'speedstar': 17,
#    'spatial': 17,
#    'slide': 17,
#    'rtrace': 17,
#    'rend': 17,
#    'raytracer': 17,
#    'playback': 17,
#    'microsoft': 17,
#    'isbn': 17,
#    'install': 17,
#    'indigo': 17,
#    'gem': 17,
#    'ff': 17,
#    'djgpp': 17,
#    'vendor': 29,
#    'modify': 29,
#    'curve': 29,
#    'appreciated': 29,
#    'visualisation': 16,
#    'turbo': 16,
#    'triangle': 16,
#    'specification': 16,
#    'prompt': 16,
#    'pcx': 16,
#    'overlay': 16,
#    'matrix': 16,
#    'lewis': 16,
#    'fotis': 16,
#    'diagram': 16,
#    'contrib': 16,
#    'comp': 16,
#    'ave': 16,
#    'parameter': 28,
#    'parallel': 28,
#    'header': 28,
#    'scale': 50,
#    'port': 50,
#    'command': 50,
#    'analysis': 114,
#    'edit': 49,
#    'compute': 49,
#    'upgrade': 27,
#    'raw': 27,
#    'protocol': 27,
#    'graph': 27,
#    'crop': 27,
#    'bbs': 27,
#    'feature': 110,
#    'bite': 48},
#   0.20025,
#   21840.0),
#  ({'hockey': 655,
#    'season': 393,
#    'playoff': 357,
#    'nhl': 350,
#    'espn': 193,
#    'det': 187,
#    'detroit': 184,
#    'coach': 165,
#    'score': 284,
#    'montreal': 161,
#    'bos': 159,
#    'league': 278,
#    'pt': 272,
#    'cup': 267,
#    'tor': 144,
#    'pen': 144,
#    'chi': 144,
#    'buffalo': 144,
#    'team': 1010,
#    'goalie': 135,
#    'bruin': 133,
#    'nyi': 131,
#    'gm': 229,
#    'calgary': 129,
#    'shark': 124,
#    'puck': 121,
#    'penguin': 120,
#    'islander': 120,
#    'devil': 120,
#    'que': 119,
#    'buf': 116,
#    'pit': 196,
#    'stl': 110,
#    'fan': 344,
#    'ranger': 190,
#    'penalty': 182,
#    'sabre': 102,
#    'oiler': 100,
#    'baseball': 100,
#    'leaf': 175,
#    'lemieux': 99,
#    'edmonton': 97,
#    'ahl': 96,
#    'mario': 92,
#    'canuck': 92,
#    'nyr': 91,
#    'captain': 91,
#    'jose': 90,
#    'ottawa': 81,
#    'fuhr': 81,
#    'abc': 81,
#    'cal': 142,
#    'sj': 80,
#    'scorer': 79,
#    'gretzky': 78,
#    'arena': 78,
#    'stanley': 137,
#    'pp': 137,
#    'draft': 136,
#    'champ': 76,
#    'sweden': 75,
#    'skate': 75,
#    'norris': 75,
#    'hawk': 74,
#    'phi': 73,
#    'edm': 73,
#    'ot': 71,
#    'wing': 213,
#    'win': 486,
#    'quebec': 118,
#    'jersey': 67,
#    'gilmour': 67,
#    'finland': 67,
#    'winnipeg': 117,
#    'ott': 66,
#    'defenseman': 66,
#    'lindros': 64,
#    'tampa': 62,
#    'har': 61,
#    'louis': 106,
#    'boston': 190,
#    'maynard': 60,
#    'jagr': 60,
#    'francis': 60,
#    'roger': 105,
#    'pittsburgh': 187,
#    'min': 104,
#    'stats': 59,
#    'overtime': 59,
#    'moncton': 59,
#    'potvin': 58,
#    'adirondack': 58,
#    'goaltender': 57,
#    'canadiens': 56,
#    'smythe': 55,
#    'goal': 390,
#    'powerplay': 54,
#    'hartford': 53,
#    'habs': 53,
#    'bure': 53,
#    'ulf': 52,
#    'defensive': 52,
#    'minnesota': 91,
#    'sport': 88,
#    'championship': 50,
#    'mtl': 48,
#    'gainey': 48,
#    'king': 151,
#    'ice': 150,
#    'whaler': 47,
#    'providence': 47,
#    'lw': 47,
#    'selanne': 82,
#    'springfield': 46,
#    'franchise': 46,
#    'van': 143,
#    'tb': 79,
#    'utica': 44,
#    'rw': 44,
#    'njd': 44,
#    'binghamton': 44,
#    'flyer': 76,
#    'isle': 43,
#    'cherry': 43,
#    'murray': 74,
#    'standing': 42,
#    'mogilny': 42,
#    'pts': 41,
#    'lafontaine': 41,
#    'finnish': 41,
#    'en': 41,
#    'breton': 41,
#    'philadelphia': 72,
#    'bay': 71,
#    'tournament': 40,
#    'probert': 40,
#    'pitt': 40,
#    'blackhawks': 40,
#    'la': 275,
#    'keenan': 38,
#    'hextall': 38,
#    'dineen': 38,
#    'gerald': 66,
#    'tie': 117,
#    'angeles': 65,
#    'savard': 37,
#    'kariya': 37,
#    'stevens': 36,
#    'ihl': 36,
#    'czech': 36,
#    'barrasso': 36,
#    'nj': 112,
#    'canadian': 112,
#    'victory': 35,
#    'pocklington': 35,
#    'murphy': 35,
#    'fredericton': 35,
#    'ecac': 35,
#    'bowman': 35,
#    'champion': 61,
#    'yzerman': 34,
#    'swedish': 34,
#    'cbc': 34,
#    'bruins': 34,
#    'shot': 240,
#    'sutter': 33,
#    'rsh': 33,
#    'rookie': 33,
#    'hull': 33,
#    'fleury': 33,
#    'coffey': 33,
#    'chelios': 33,
#    'calder': 33,
#    'attendance': 33,
#    'mon': 102,
#    'wc': 31,
#    'neely': 31,
#    'hunter': 31,
#    'halifax': 31,
#    'cdi': 31,
#    'rochester': 54,
#    'gld': 53,
#    'trophy': 30,
#    'tocchet': 30,
#    'soderstrom': 30,
#    'slash': 30,
#    'shanahan': 30,
#    'sh': 30,
#    'mullen': 30,
#    'messier': 30,
#    'maine': 30,
#    'hrivnak': 30,
#    'hammerl': 30,
#    'courtnall': 30,
#    'patrick': 94,
#    'talent': 52,
#    'sandstrom': 29,
#    'sanderson': 29,
#    'pim': 29,
#    'pgh': 29,
#    'scoring': 28,
#    'referee': 28,
#    'penguins': 28,
#    'oates': 28,
#    'denis': 28,
#    'rauser': 27,
#    'nordiques': 27,
#    'milwaukee': 27,
#    'cgy': 27,
#    'carson': 27,
#    'belfour': 27,
#    'coverage': 85,
#    'watch': 193,
#    'cap': 83,
#    'kevin': 46,
#    'acquire': 46,
#    'vernon': 26,
#    'stauber': 26,
#    'semifinal': 26,
#    'roster': 26,
#    'quinn': 26,
#    'offense': 26,
#    'nords': 26,
#    'moog': 26,
#    'macinnis': 26,
#    'johansson': 26,
#    'cordially': 26,
#    'tsn': 25,
#    'robitaille': 25,
#    'octopus': 25,
#    'breaker': 25,
#    'bellow': 25,
#    'andersson': 25,
#    'senator': 43,
#    'mighty': 24,
#    'miami': 24,
#    'linden': 24,
#    'kovalev': 24,
#    'kisio': 24,
#    'goaltending': 24,
#    'disappointment': 24,
#    'bobby': 24,
#    'mask': 42,
#    'trade': 171,
#    'ticket': 41,
#    'cape': 41,
#    'wpg': 23,
#    'teemu': 23,
#    'selnne': 23,
#    'roenick': 23,
#    'randy': 23,
#    'defensemen': 23,
#    'damphousse': 23,
#    'bettman': 23,
#    'roy': 72,
#    'mvp': 40,
#    'expansion': 40,
#    'vs': 71,
#    'night': 162,
#    'winner': 70,
#    'suck': 39,
#    'deserve': 39,
#    'toronto': 160,
#    'turgeon': 22,
#    'slot': 22,
#    'phoenix': 22,
#    'nelson': 22,
#    'ncaa': 22,
#    'hawerchuk': 22,
#    'ferraro': 22,
#    'bourque': 22,
#    'announcer': 22,
#    'jet': 157,
#    'wayne': 37,
#    'suter': 21,
#    'ronning': 21,
#    'nylander': 21,
#    'moron': 21,
#    'keller': 21,
#    'golf': 21,
#    'basketball': 21,
#    'asshole': 21,
#    'streak': 20,
#    'staffan': 20,
#    'rating': 20,
#    'norway': 20,
#    'mcgill': 20,
#    'kelly': 20,
#    'granato': 20,
#    'gartner': 20,
#    'fame': 20,
#    'essensa': 20,
#    'daigle': 20,
#    'clarkson': 20,
#    'championships': 20,
#    'bench': 20,
#    'austria': 20,
#    'vancouver': 144,
#    'injury': 60,
#    'stewart': 19},
#   0.201,
#   24847.0),
#  ({'disease': 380,
#    'infection': 206,
#    'doctor': 344,
#    'hiv': 192,
#    'cancer': 323,
#    'treatment': 272,
#    'drug': 258,
#    'candida': 129,
#    'patient': 406,
#    'yeast': 127,
#    'msg': 213,
#    'symptom': 120,
#    'clinical': 118,
#    'therapy': 107,
#    'quack': 101,
#    'hicnet': 94,
#    'syndrome': 93,
#    'food': 293,
#    'health': 289,
#    'pain': 159,
#    'diet': 156,
#    'cell': 88,
#    'kidney': 82,
#    'sinus': 81,
#    'vitamin': 80,
#    'cure': 79,
#    'vaccine': 77,
#    'illness': 76,
#    'chronic': 74,
#    'antibiotic': 72,
#    'physician': 125,
#    'diagnose': 66,
#    'lyme': 65,
#    'hypothesis': 64,
#    'geb': 64,
#    'fat': 64,
#    'chinese': 64,
#    'newsletter': 112,
#    'hospital': 112,
#    'skepticism': 63,
#    'ear': 63,
#    'breast': 63,
#    'jxp': 61,
#    'intellect': 61,
#    'chastity': 61,
#    'shameful': 60,
#    'prevention': 59,
#    'allergy': 58,
#    'diagnosis': 57,
#    'nutrition': 55,
#    'migraine': 54,
#    'bloom': 54,
#    'medical': 388,
#    'restaurant': 53,
#    'gordon': 93,
#    'severe': 51,
#    'allergic': 51,
#    'immune': 49,
#    'dyer': 49,
#    'trial': 83,
#    'stone': 83,
#    'oral': 47,
#    'medication': 47,
#    'needle': 46,
#    'bone': 46,
#    'antifungal': 46,
#    'photography': 45,
#    'anecdotal': 43,
#    'tissue': 42,
#    'liver': 42,
#    'vaginal': 41,
#    'glutamate': 41,
#    'gi': 41,
#    'calcium': 41,
#    'malaria': 40,
#    'infect': 39,
#    'infant': 39,
#    'cdc': 39,
#    'muscle': 68,
#    'virus': 38,
#    'noring': 37,
#    'empirical': 37,
#    'tobacco': 64,
#    'prescribe': 36,
#    'disorder': 36,
#    'risk': 111,
#    'infectious': 35,
#    'hernia': 35,
#    'gut': 35,
#    'fda': 35,
#    'surrender': 60,
#    'acid': 60,
#    'yogurt': 34,
#    'systemic': 34,
#    'inflammation': 34,
#    'headache': 34,
#    'child': 104,
#    'vagina': 33,
#    'outbreak': 33,
#    'nerve': 33,
#    'milk': 33,
#    'membrane': 33,
#    'intake': 33,
#    'surgeon': 32,
#    'organism': 32,
#    'med': 32,
#    'mg': 56,
#    'russell': 31,
#    'rind': 31,
#    'placebo': 31,
#    'dose': 31,
#    'dietary': 31,
#    'protein': 30,
#    'meat': 30,
#    'kirlian': 30,
#    'hepatitis': 30,
#    'finding': 30,
#    'tract': 29,
#    'water': 91,
#    'mucus': 28,
#    'aura': 28,
#    'substance': 48,
#    'animal': 48,
#    'ultrasound': 27,
#    'react': 27,
#    'pregnancy': 27,
#    'pill': 27,
#    'lung': 27,
#    'ingredient': 27,
#    'clinic': 47,
#    'bacteria': 46,
#    'thyroid': 26,
#    'skin': 81,
#    'taste': 45,
#    'sugar': 25,
#    'stomach': 25,
#    'radiologist': 25,
#    'practitioner': 25,
#    'intestine': 25,
#    'fluid': 25,
#    'antihistamine': 25,
#    'smoking': 24,
#    'nystatin': 24,
#    'fever': 24,
#    'cholesterol': 24,
#    'carl': 24,
#    'additive': 24,
#    'aid': 173,
#    'smoke': 42,
#    'birth': 41,
#    'diabetes': 23,
#    'corn': 23,
#    'biochemistry': 23,
#    'bath': 23,
#    'asthma': 23,
#    'antibody': 23,
#    'acidophilus': 23,
#    'medicine': 164,
#    'surgery': 71,
#    'researcher': 70,
#    'strain': 22,
#    'sensitivity': 22,
#    'massage': 22,
#    'inject': 22,
#    'infj': 22,
#    'discharge': 22,
#    'crohn': 22,
#    'eat': 158,
#    'exercise': 69,
#    'reaction': 68,
#    'remedy': 21,
#    'persistent': 21,
#    'krillean': 21,
#    'diarrhea': 21,
#    'deficiency': 21,
#    'page': 150,
#    'xrays': 20,
#    'tumor': 20,
#    'swell': 20,
#    'supplement': 20,
#    'sporanox': 20,
#    'sensitive': 20,
#    'resistance': 20,
#    'nci': 20,
#    'homeopathy': 20,
#    'fungus': 20,
#    'cream': 20,
#    'banschbach': 20,
#    'amino': 20,
#    'transmission': 35,
#    'dry': 34,
#    'chemical': 60,
#    'nih': 19,
#    'meal': 19,
#    'dominance': 19,
#    'distress': 19,
#    'ct': 19,
#    'human': 136,
#    'healthy': 33,
#    'evidence': 133,
#    'nose': 32,
#    'biology': 32,
#    'surgical': 18,
#    'sting': 18,
#    'prozac': 18,
#    'profession': 18,
#    'obesity': 18,
#    'nutritional': 18,
#    'neuron': 18,
#    'imaharvardrayssdlinusm': 18,
#    'howard': 18,
#    'hivpositive': 18,
#    'glucose': 18,
#    'gland': 18,
#    'genetic': 18,
#    'flavor': 18,
#    'doubleblind': 18,
#    'cspdccdyer': 18,
#    'cereal': 18,
#    'carcinogenic': 18,
#    'biopsy': 18,
#    'bacterial': 18,
#    'approval': 18,
#    'dr': 129,
#    'lab': 55,
#    'advice': 54,
#    'fantasy': 30,
#    'stool': 17,
#    'relieve': 17,
#    'recur': 17,
#    'progression': 17,
#    'painful': 17,
#    'licensed': 17,
#    'lesion': 17,
#    'doyle': 17,
#    'dna': 17,
#    'discomfort': 17,
#    'dentist': 17,
#    'consumption': 17,
#    'albicans': 17,
#    'accepted': 17,
#    'scientific': 120,
#    'treat': 116,
#    'thrush': 16,
#    'steroid': 16,
#    'resident': 16,
#    'olneys': 16,
#    'mri': 16,
#    'kekule': 16,
#    'incidence': 16,
#    'heal': 16,
#    'fruit': 16,
#    'fresh': 16,
#    'burzynskis': 16,
#    'beef': 16,
#    'acute': 16,
#    'tb': 28,
#    'dos': 28,
#    'depression': 28,
#    'seizure': 27,
#    'school': 110,
#    'vaseline': 15,
#    'toxin': 15,
#    'sa': 15,
#    'recurrence': 15,
#    'recipe': 15,
#    'mild': 15,
#    'lancet': 15,
#    'invasive': 15,
#    'inflammatory': 15,
#    'healthcare': 15,
#    'haldol': 15,
#    'gilbert': 15,
#    'endometriosis': 15,
#    'dizziness': 15,
#    'commonly': 15,
#    'colon': 15,
#    'clothes': 15,
#    'circumcision': 15,
#    'chocolate': 15,
#    'chest': 15,
#    'bee': 15,
#    'antidepressant': 15,
#    'acupuncture': 15,
#    'culture': 47,
#    'mouse': 26,
#    'methodology': 26,
#    'leg': 26,
#    'adult': 26,
#    'blood': 106,
#    'stress': 25,
#    'leaf': 25,
#    'insurance': 25,
#    'helpful': 25,
#    'formation': 25,
#    'viral': 14,
#    'tea': 14,
#    'spelling': 14,
#    'snake': 14,
#    'rutin': 14},
#   0.19525,
#   16880.0),
#  ({'orbit': 376,
#    'shuttle': 285,
#    'spacecraft': 229,
#    'solar': 219,
#    'nasa': 322,
#    'launch': 506,
#    'moon': 277,
#    'lunar': 152,
#    'venus': 151,
#    'henry': 150,
#    'sky': 145,
#    'planet': 234,
#    'hst': 115,
#    'orbital': 102,
#    'flight': 174,
#    'burst': 99,
#    'comet': 92,
#    'mar': 161,
#    'payload': 88,
#    'telescope': 86,
#    'jupiter': 86,
#    'titan': 85,
#    'planetary': 82,
#    'kilometer': 80,
#    'propulsion': 78,
#    'orbiter': 78,
#    'billboard': 78,
#    'pluto': 77,
#    'astronaut': 77,
#    'atmosphere': 133,
#    'spencer': 74,
#    'vehicle': 128,
#    'probe': 121,
#    'saturn': 65,
#    'dcx': 64,
#    'exploration': 63,
#    'baalke': 62,
#    'billion': 106,
#    'observatory': 60,
#    'altitude': 60,
#    'radar': 59,
#    'detector': 58,
#    'galileo': 57,
#    'asteroid': 56,
#    'voyager': 54,
#    'antenna': 54,
#    'zoology': 52,
#    'prize': 52,
#    'higgins': 52,
#    'utzoohenry': 50,
#    'ssto': 50,
#    'earth': 356,
#    'fuel': 85,
#    'kg': 47,
#    'temperature': 81,
#    'launcher': 46,
#    'delta': 46,
#    'satellite': 325,
#    'mission': 325,
#    'magellan': 45,
#    'craft': 45,
#    'booster': 45,
#    'astronomer': 45,
#    'proton': 44,
#    'pad': 44,
#    'fred': 44,
#    'cloud': 76,
#    'military': 74,
#    'km': 74,
#    'engine': 74,
#    'nsmca': 42,
#    'mercury': 42,
#    'liquid': 41,
#    'surface': 127,
#    'magnetic': 40,
#    'lander': 40,
#    'thermal': 39,
#    'centaur': 39,
#    'balloon': 38,
#    'aerospace': 38,
#    'sail': 37,
#    'leo': 37,
#    'inflatable': 37,
#    'array': 64,
#    'mass': 114,
#    'meter': 36,
#    'flyby': 36,
#    'crew': 36,
#    'collision': 36,
#    'instrument': 63,
#    'command': 112,
#    'velocity': 35,
#    'trajectory': 35,
#    'timer': 35,
#    'redesign': 35,
#    'pioneer': 35,
#    'mariner': 35,
#    'gif': 60,
#    'reboost': 34,
#    'earths': 34,
#    'atmospheric': 34,
#    'viking': 33,
#    'oxygen': 33,
#    'halo': 33,
#    'ames': 33,
#    'overhead': 32,
#    'funding': 55,
#    'uranus': 31,
#    'ssf': 31,
#    'physicist': 31,
#    'neptune': 31,
#    'gravity': 54,
#    'gamma': 54,
#    'data': 221,
#    'government': 95,
#    'pilot': 30,
#    'pasadena': 30,
#    'landing': 30,
#    'infrared': 30,
#    'hopkins': 30,
#    'dust': 30,
#    'acceleration': 30,
#    'observer': 52,
#    'radiation': 51,
#    'astronomical': 51,
#    'oort': 29,
#    'martian': 29,
#    'belt': 29,
#    'spin': 28,
#    'josh': 28,
#    'highspeed': 28,
#    'gehrels': 28,
#    'venture': 48,
#    'tank': 48,
#    'svr': 48,
#    'shafer': 27,
#    'prb': 27,
#    'moscow': 27,
#    'dryden': 27,
#    'diameter': 27,
#    'boeing': 27,
#    'au': 27,
#    'energy': 85,
#    'module': 47,
#    'activity': 84,
#    'jpl': 46,
#    'gas': 46,
#    'thruster': 26,
#    'ocean': 26,
#    'neutron': 26,
#    'kipling': 26,
#    'crater': 26,
#    'cosmic': 26,
#    'aviation': 26,
#    'ariane': 26,
#    'hardware': 45,
#    'galaxy': 45,
#    'drag': 44,
#    'reston': 25,
#    'pole': 25,
#    'dunn': 25,
#    'atlas': 25,
#    'radius': 43,
#    'spaceflight': 24,
#    'sdio': 24,
#    'jbh': 24,
#    'interstellar': 24,
#    'galactic': 24,
#    'ozone': 42,
#    'rocket': 169,
#    'plane': 41,
#    'advertising': 41,
#    'palmer': 23,
#    'fraering': 23,
#    'bright': 39,
#    'telos': 22,
#    'nasas': 22,
#    'mcdonnell': 22,
#    'gravitational': 22,
#    'celestial': 22,
#    'cassini': 22,
#    'boost': 22,
#    'beam': 22,
#    'soviet': 67,
#    'ground': 67,
#    'apollo': 37,
#    'smiley': 21,
#    'rocketry': 21,
#    'polar': 21,
#    'outer': 21,
#    'oms': 21,
#    'knox': 21,
#    'deg': 21,
#    'contest': 21,
#    'particle': 36,
#    'wrap': 20,
#    'mystery': 20,
#    'clipper': 20,
#    'allen': 63,
#    'station': 144,
#    'pollution': 35,
#    'nuclear': 35,
#    'dennis': 35,
#    'investment': 34,
#    'usaf': 19,
#    'uranium': 19,
#    'technological': 19,
#    'stable': 19,
#    'spectrometer': 19,
#    'reusable': 19,
#    'relay': 19,
#    'pegasus': 19,
#    'optical': 19,
#    'noop': 19,
#    'navigation': 19,
#    'museum': 19,
#    'kjenks': 19,
#    'hydrogen': 19,
#    'esa': 19,
#    'dock': 19,
#    'deploy': 19,
#    'debris': 19,
#    'batse': 19,
#    'image': 136,
#    'distance': 58,
#    'aircraft': 32,
#    'ultraviolet': 18,
#    'telemetry': 18,
#    'spherical': 18,
#    'mir': 18,
#    'mining': 18,
#    'miner': 18,
#    'margin': 18,
#    'dietz': 18,
#    'cosmological': 18,
#    'caterpillar': 18,
#    'burster': 18,
#    'aweto': 18,
#    'arizona': 18,
#    'yamauchi': 17,
#    'tracking': 17,
#    'spare': 17,
#    'mag': 17,
#    'karl': 17,
#    'isotropic': 17,
#    'iron': 17,
#    'interplanetary': 17,
#    'hga': 17,
#    'hannibal': 17,
#    'explorer': 17,
#    'emission': 17,
#    'cruise': 17,
#    'beauty': 17,
#    'alien': 17,
#    'wind': 29,
#    'resemble': 29,
#    'object': 119,
#    'private': 51,
#    'ulysses': 16,
#    'tilt': 16,
#    'sensor': 16,
#    'prototype': 16,
#    'operational': 16,
#    'nicho': 16,
#    'mayan': 16,
#    'jsc': 16,
#    'griffin': 16,
#    'energetic': 16,
#    'dragless': 16,
#    'comprehensive': 16,
#    'coffee': 16,
#    'cm': 16,
#    'churchill': 16,
#    'arc': 16,
#    'tommy': 28,
#    'approximately': 28,
#    'adams': 28,
#    'motion': 50,
#    'pat': 114,
#    'integration': 27,
#    'explore': 27,
#    'bay': 27,
#    'degree': 110,
#    'worden': 15,
#    'televison': 15,
#    'ssrt': 15,
#    'repo': 15,
#    'nearby': 15,
#    'madam': 15,
#    'keithley': 15,
#    'journey': 15,
#    'jenks': 15,
#    'grbs': 15,
#    'gammaray': 15,
#    'er': 15,
#    'digest': 15,
#    'constellation': 15,
#    'chlorine': 15,
#    'charon': 15,
#    'astor': 15},
#   0.19875,
#   17225.0),
#  ({'stephanopoulos': 325,
#    'homosexual': 261,
#    'government': 697,
#    'abortion': 207,
#    'gay': 197,
#    'fbi': 194,
#    'crime': 155,
#    'koresh': 146,
#    'cramer': 143,
#    'batf': 141,
#    'insurance': 245,
#    'law': 438,
#    'clayton': 130,
#    'drug': 218,
#    'libertarian': 123,
#    'police': 122,
#    'murder': 113,
#    'constitution': 105,
#    'warrant': 103,
#    'kinsey': 103,
#    'tax': 317,
#    'child': 313,
#    'attorney': 99,
#    'health': 305,
#    'officer': 91,
#    'president': 651,
#    'bd': 90,
#    'sexual': 157,
#    'republican': 89,
#    'justice': 88,
#    'consent': 84,
#    'senate': 82,
#    'dee': 82,
#    'reform': 81,
#    'waco': 80,
#    'holocaust': 78,
#    'religion': 77,
#    'court': 135,
#    'davidians': 75,
#    'private': 232,
#    'deficit': 72,
#    'freedom': 124,
#    'liberal': 69,
#    'male': 120,
#    'military': 118,
#    'secretary': 116,
#    'party': 205,
#    'mutual': 65,
#    'kaldis': 64,
#    'vat': 62,
#    'clinton': 195,
#    'uunetpyramidoptilinkcramer': 61,
#    'gun': 190,
#    'witness': 60,
#    'convention': 60,
#    'atf': 60,
#    'amendment': 60,
#    'democracy': 59,
#    'phill': 58,
#    'election': 58,
#    'religious': 101,
#    'homosexuality': 57,
#    'heterosexual': 57,
#    'evil': 57,
#    'criminal': 57,
#    'bush': 57,
#    'stimulus': 54,
#    'reno': 54,
#    'economy': 94,
#    'compound': 94,
#    'conversation': 53,
#    'trial': 93,
#    'survivor': 52,
#    'arrest': 52,
#    'economic': 90,
#    'raid': 51,
#    'promiscuous': 51,
#    'enforcement': 51,
#    'federal': 159,
#    'irrelevant': 50,
#    'church': 50,
#    'security': 49,
#    'cult': 49,
#    'gas': 86,
#    'administration': 146,
#    'labor': 46,
#    'boomer': 46,
#    'sex': 143,
#    'impose': 45,
#    'democratic': 45,
#    'bosnia': 45,
#    'nuclear': 79,
#    'welfare': 44,
#    'assault': 44,
#    'jewish': 43,
#    'commit': 74,
#    'violate': 42,
#    'israel': 42,
#    'campaign': 42,
#    'secret': 73,
#    'jury': 41,
#    'jew': 41,
#    'hallambaker': 41,
#    'billion': 72,
#    'fed': 40,
#    'council': 40,
#    'weapon': 70,
#    'income': 70,
#    'abuse': 70,
#    'discrimination': 39,
#    'constitutional': 39,
#    'senator': 67,
#    'tear': 38,
#    'supreme': 38,
#    'dole': 38,
#    'democrat': 38,
#    'moral': 65,
#    'doctor': 65,
#    'slave': 37,
#    'laughter': 37,
#    'garrett': 37,
#    'conservative': 37,
#    'briefing': 37,
#    'liberty': 36,
#    'iran': 36,
#    'ally': 36,
#    'country': 255,
#    'men': 254,
#    'suicide': 35,
#    'queer': 35,
#    'lord': 35,
#    'edt': 35,
#    'conviction': 35,
#    'population': 110,
#    'enemy': 34,
#    'minority': 105,
#    'socialist': 33,
#    'reagan': 33,
#    'minister': 33,
#    'fuck': 33,
#    'cop': 33,
#    'russia': 103,
#    'nation': 101,
#    'coverage': 100,
#    'ted': 55,
#    'rape': 31,
#    'politician': 31,
#    'plaintiff': 31,
#    'koreshs': 31,
#    'hitler': 31,
#    'violation': 30,
#    'theodore': 30,
#    'premium': 30,
#    'noknock': 30,
#    'mob': 30,
#    'cigarette': 30,
#    'appeal': 30,
#    'war': 214,
#    'house': 211,
#    'citizen': 92,
#    'treatment': 51,
#    'speech': 51,
#    'foreign': 51,
#    'engage': 51,
#    'legislation': 29,
#    'guilty': 29,
#    'follower': 29,
#    'britain': 29,
#    'ground': 90,
#    'regulation': 50,
#    'parent': 50,
#    'investment': 50,
#    'agenda': 50,
#    'social': 89,
#    'teel': 28,
#    'pork': 28,
#    'jefferson': 28,
#    'grenade': 28,
#    'firearm': 28,
#    'affair': 28,
#    'victim': 49,
#    'veto': 27,
#    'tactic': 27,
#    'hostage': 27,
#    'dramatically': 27,
#    'disaster': 27,
#    'cnn': 27,
#    'civil': 85,
#    'activity': 85,
#    'initiative': 47,
#    'political': 190,
#    'spending': 46,
#    'yeltsin': 26,
#    'terrorist': 26,
#    'reich': 26,
#    'provision': 26,
#    'peaceful': 26,
#    'mormon': 26,
#    'governor': 26,
#    'genocide': 26,
#    'compel': 26,
#    'gld': 45,
#    'commitment': 45,
#    'partner': 79,
#    'canadian': 79,
#    'tank': 44,
#    'naval': 44,
#    'thf': 25,
#    'socialism': 25,
#    'sept': 25,
#    'nazi': 25,
#    'gaybi': 25,
#    'exclusively': 25,
#    'bastard': 25,
#    'african': 25,
#    'branch': 78,
#    'peace': 43,
#    'agent': 77,
#    'troop': 24,
#    'territory': 24,
#    'marijuana': 24,
#    'libertarianism': 24,
#    'legislative': 24,
#    'innocent': 24,
#    'hendricks': 24,
#    'enforce': 24,
#    'bomb': 24,
#    'representative': 42,
#    'hospital': 42,
#    'illegal': 74,
#    'human': 169,
#    'sector': 41,
#    'hire': 41,
#    'verdict': 23,
#    'settlement': 23,
#    'propaganda': 23,
#    'median': 23,
#    'involvement': 23,
#    'insurer': 23,
#    'inevitable': 23,
#    'immunization': 23,
#    'hide': 23,
#    'elses': 23,
#    'crisis': 23,
#    'truth': 40,
#    'meeting': 71,
#    'senior': 70,
#    'janet': 39,
#    'govt': 39,
#    'trust': 22,
#    'steveh': 22,
#    'riley': 22,
#    'poverty': 22,
#    'objection': 22,
#    'mitchell': 22,
#    'justification': 22,
#    'gridlock': 22,
#    'fraud': 22,
#    'deviant': 22,
#    'conspiracy': 22,
#    'chamber': 22,
#    'bi': 22,
#    'abolish': 22,
#    'authority': 69,
#    'relationship': 38,
#    'navy': 38,
#    'attack': 68,
#    'vice': 37,
#    'funding': 37,
#    'angeles': 37,
#    'wdstarr': 21,
#    'tenant': 21,
#    'neighborhood': 21,
#    'legally': 21,
#    'legalize': 21,
#    'ignorant': 21,
#    'charity': 21,
#    'adjective': 21,
#    'employee': 36,
#    'package': 146,
#    'kill': 146,
#    'supporter': 20,
#    'statute': 20,
#    'sanction': 20,
#    'pythagorean': 20,
#    'nixon': 20,
#    'nambla': 20,
#    'molestation': 20,
#    'intent': 20,
#    'immoral': 20,
#    'guard': 20,
#    'finance': 20,
#    'cultural': 20,
#    'convict': 20,
#    'bash': 20,
#    'ballot': 20,
#    'allege': 20,
#    'ignore': 63,
#    'evidence': 142,
#    'congress': 141},
#   0.20475,
#   22298.0)]

# %%
joblib.dump(lookup_table_80_20,"lookup_table_80_20")
# Out:
# ['lookup_table_80_20']

# %%
len(lookup_table_80_20[1][0].keys())
# Out:
# 300

# %%
joblib.dump(lookup_table_80_20,'lookup_table_80_20')
# Out:
# ['lookup_table_80_20']

# %%
def test_naive_bayes(sentence, lookup_table):
    likelihood = np.zeros(len(unique_classes))
    words = [str(word) for word in sentence.split(" ")]
    for label_index,index in enumerate(unique_classes):
        for word in words:
            # likelihood = count(word)+1 / vocab + word_counts_in_class
            likelihood[label_index] += np.log((lookup_table[label_index][0].get(word,0)+1) /(float(lookup_table[label_index][2])))
    posterior = np.empty(len(unique_classes))
    for label_index,label in enumerate(unique_classes):
        posterior[label_index] = np.log(lookup_table[label_index][1])+ likelihood[label_index]
    return unique_classes[np.argmax(posterior)]

# %%
unique_classes=list(set(train_80_20['label'].values))

# %%
test_80_20['text'] = test_80_20['text'].astype(str)

# %%
predictions = test_80_20['text'].apply(lambda x: test_naive_bayes(x,lookup_table_80_20))

# %%
predictions.values
# Out:
# array([2, 0, 4, 4, 4, 1, 3, 0, 2, 3, 3, 2, 2, 3, 2, 0, 0, 2, 2, 1, 1, 4,
#        2, 4, 2, 2, 1, 1, 1, 3, 3, 1, 0, 1, 2, 3, 1, 3, 0, 4, 1, 2, 3, 3,
#        0, 2, 2, 2, 4, 4, 3, 1, 3, 3, 2, 2, 2, 0, 3, 3, 4, 2, 2, 0, 4, 2,
#        3, 2, 2, 3, 4, 3, 2, 2, 4, 2, 3, 4, 2, 2, 2, 0, 1, 1, 0, 3, 3, 1,
#        2, 3, 1, 1, 2, 3, 2, 1, 0, 2, 3, 4, 3, 4, 4, 2, 3, 1, 1, 3, 2, 2,
#        0, 0, 2, 2, 4, 1, 4, 2, 1, 2, 2, 3, 1, 3, 4, 0, 4, 1, 2, 4, 2, 2,
#        2, 0, 1, 4, 1, 2, 3, 3, 0, 3, 3, 2, 2, 1, 0, 1, 3, 4, 3, 4, 1, 1,
#        1, 1, 1, 2, 2, 2, 0, 0, 3, 2, 4, 1, 0, 3, 4, 3, 1, 0, 3, 4, 1, 3,
#        4, 4, 0, 2, 2, 1, 1, 4, 4, 0, 2, 3, 2, 3, 3, 2, 4, 2, 3, 0, 1, 1,
#        3, 3, 0, 2, 4, 4, 3, 1, 4, 0, 1, 1, 2, 2, 0, 2, 2, 1, 2, 3, 3, 2,
#        4, 0, 3, 3, 1, 0, 3, 2, 4, 0, 3, 0, 2, 2, 2, 2, 2, 2, 0, 0, 4, 2,
#        2, 1, 2, 4, 4, 3, 1, 2, 2, 4, 4, 3, 3, 4, 2, 1, 3, 1, 2, 1, 4, 4,
#        4, 3, 2, 4, 4, 2, 2, 3, 1, 1, 0, 0, 3, 2, 4, 0, 2, 3, 0, 1, 2, 3,
#        3, 0, 2, 0, 2, 2, 0, 2, 4, 2, 1, 1, 4, 4, 2, 2, 2, 1, 4, 3, 1, 3,
#        4, 4, 2, 1, 1, 1, 2, 1, 0, 2, 3, 2, 2, 2, 2, 1, 0, 2, 3, 2, 3, 3,
#        3, 3, 2, 3, 1, 2, 0, 3, 3, 3, 0, 1, 3, 3, 3, 4, 1, 2, 2, 2, 3, 3,
#        0, 2, 3, 1, 3, 1, 1, 2, 3, 4, 2, 3, 2, 3, 0, 3, 2, 0, 2, 3, 3, 3,
#        3, 1, 1, 3, 4, 2, 0, 4, 1, 2, 1, 2, 0, 1, 1, 3, 0, 2, 3, 0, 4, 2,
#        4, 3, 4, 4, 2, 3, 1, 1, 1, 4, 3, 4, 0, 2, 4, 1, 2, 1, 2, 3, 0, 1,
#        2, 4, 1, 2, 2, 3, 3, 0, 0, 0, 3, 3, 2, 4, 3, 1, 1, 4, 2, 3, 2, 4,
#        0, 1, 0, 2, 3, 3, 0, 1, 0, 2, 3, 3, 2, 0, 0, 3, 3, 2, 1, 3, 4, 3,
#        2, 0, 2, 1, 2, 2, 2, 3, 1, 2, 4, 2, 4, 0, 3, 2, 0, 0, 3, 2, 0, 2,
#        4, 3, 0, 3, 0, 2, 2, 2, 3, 3, 4, 1, 4, 4, 2, 1, 1, 3, 3, 1, 0, 0,
#        1, 3, 2, 2, 2, 0, 0, 4, 2, 0, 0, 1, 2, 2, 2, 2, 2, 1, 2, 1, 4, 3,
#        0, 3, 1, 3, 3, 1, 3, 3, 4, 2, 3, 1, 2, 0, 2, 3, 3, 0, 1, 2, 2, 4,
#        3, 2, 2, 3, 2, 2, 0, 1, 3, 0, 0, 0, 4, 2, 0, 0, 0, 1, 2, 0, 1, 2,
#        1, 2, 2, 0, 0, 4, 2, 1, 2, 2, 2, 2, 0, 4, 3, 2, 1, 2, 3, 3, 2, 1,
#        2, 3, 3, 2, 3, 3, 1, 0, 3, 4, 3, 3, 0, 3, 1, 0, 0, 1, 2, 3, 2, 3,
#        0, 0, 2, 2, 0, 1, 2, 3, 0, 0, 4, 3, 0, 2, 2, 3, 2, 1, 3, 4, 3, 0,
#        3, 0, 3, 2, 1, 0, 4, 3, 2, 1, 2, 3, 2, 1, 3, 4, 1, 0, 3, 1, 1, 2,
#        2, 4, 4, 3, 2, 2, 4, 1, 4, 3, 1, 1, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3,
#        1, 0, 0, 1, 2, 1, 1, 3, 1, 4, 2, 0, 4, 2, 2, 3, 3, 2, 0, 3, 4, 0,
#        4, 2, 3, 2, 2, 2, 1, 2, 3, 0, 1, 0, 2, 0, 2, 0, 2, 2, 1, 3, 0, 2,
#        3, 3, 2, 0, 4, 4, 2, 1, 3, 2, 2, 0, 3, 0, 4, 0, 2, 0, 0, 2, 0, 4,
#        0, 2, 4, 0, 0, 4, 4, 2, 2, 0, 0, 1, 1, 1, 3, 4, 2, 0, 3, 0, 3, 2,
#        2, 4, 0, 4, 1, 2, 1, 1, 2, 2, 2, 4, 2, 3, 3, 2, 0, 2, 0, 4, 1, 0,
#        4, 2, 3, 2, 2, 2, 2, 3, 3, 2, 3, 2, 4, 4, 3, 2, 3, 4, 1, 4, 1, 2,
#        1, 1, 3, 1, 2, 1, 4, 4, 1, 4, 2, 4, 2, 0, 3, 1, 0, 2, 2, 2, 3, 0,
#        2, 2, 1, 0, 3, 2, 3, 3, 2, 2, 3, 2, 1, 2, 2, 2, 3, 2, 2, 2, 1, 3,
#        2, 2, 4, 0, 2, 0, 3, 2, 4, 3, 1, 2, 4, 4, 3, 0, 3, 4, 3, 2, 2, 4,
#        0, 1, 2, 0, 3, 2, 3, 3, 2, 1, 0, 2, 1, 1, 1, 2, 0, 1, 0, 0, 3, 0,
#        3, 4, 3, 1, 1, 1, 2, 4, 0, 3, 0, 0, 1, 3, 1, 3, 3, 1, 2, 2, 1, 0,
#        3, 3, 2, 2, 2, 3, 1, 2, 1, 0, 2, 2, 2, 2, 3, 0, 1, 2, 3, 2, 3, 2,
#        2, 2, 1, 0, 2, 1, 2, 3, 3, 2, 1, 2, 2, 2, 3, 2, 3, 2, 0, 3, 3, 2,
#        2, 1, 3, 2, 1, 4, 2, 4, 1, 2, 4, 1, 2, 2, 3, 0, 2, 2, 0, 0, 3, 2,
#        2, 3, 2, 1, 2, 3, 1, 2, 1, 2])

# %%
test_labels = LE.transform(test_80_20['label'].values)
test_labels
# Out:
# array([2, 0, 4, 4, 1, 1, 1, 0, 0, 0, 3, 2, 0, 3, 0, 0, 0, 2, 2, 1, 1, 4,
#        2, 4, 2, 4, 1, 1, 1, 0, 0, 1, 0, 1, 2, 3, 1, 3, 0, 4, 1, 2, 4, 4,
#        0, 2, 4, 2, 4, 4, 3, 1, 3, 3, 4, 0, 2, 0, 1, 3, 4, 2, 2, 0, 4, 2,
#        3, 4, 2, 0, 4, 3, 2, 2, 4, 2, 3, 4, 2, 4, 2, 0, 1, 1, 0, 3, 1, 1,
#        2, 3, 1, 1, 2, 3, 2, 1, 0, 4, 3, 4, 4, 4, 4, 2, 3, 1, 2, 3, 2, 2,
#        0, 0, 1, 3, 4, 1, 4, 0, 1, 4, 3, 3, 1, 3, 4, 0, 4, 1, 0, 4, 2, 2,
#        4, 0, 1, 4, 1, 2, 3, 3, 0, 3, 3, 4, 2, 1, 0, 1, 1, 4, 3, 4, 1, 1,
#        1, 1, 1, 4, 4, 2, 0, 0, 0, 2, 4, 1, 0, 3, 4, 0, 1, 0, 3, 4, 1, 3,
#        4, 4, 0, 2, 4, 1, 1, 4, 4, 0, 2, 3, 2, 3, 3, 4, 4, 2, 3, 0, 1, 1,
#        3, 3, 0, 2, 4, 4, 3, 1, 4, 0, 1, 1, 2, 1, 0, 1, 2, 0, 2, 3, 0, 2,
#        4, 0, 1, 3, 1, 0, 3, 2, 4, 1, 3, 2, 2, 2, 2, 2, 2, 2, 0, 0, 4, 2,
#        4, 1, 2, 4, 4, 3, 1, 0, 2, 4, 4, 3, 3, 4, 2, 1, 3, 1, 2, 1, 4, 4,
#        4, 0, 0, 4, 4, 1, 2, 3, 1, 1, 0, 0, 3, 2, 4, 0, 2, 3, 0, 1, 2, 3,
#        3, 0, 3, 0, 2, 2, 0, 2, 4, 0, 1, 1, 4, 4, 2, 2, 0, 1, 4, 3, 1, 3,
#        4, 4, 2, 1, 1, 1, 2, 1, 0, 2, 3, 2, 4, 2, 2, 1, 0, 4, 3, 2, 3, 3,
#        3, 0, 2, 3, 1, 2, 0, 3, 4, 0, 0, 1, 3, 3, 3, 4, 1, 2, 2, 4, 3, 3,
#        0, 2, 3, 1, 2, 1, 1, 2, 3, 4, 4, 4, 2, 3, 0, 2, 3, 0, 2, 3, 3, 3,
#        3, 1, 1, 3, 4, 2, 0, 4, 1, 2, 1, 2, 0, 1, 1, 4, 0, 2, 3, 0, 4, 2,
#        4, 3, 4, 4, 2, 3, 1, 1, 4, 4, 3, 4, 3, 2, 4, 1, 1, 1, 2, 3, 0, 1,
#        0, 4, 1, 2, 4, 3, 3, 0, 0, 0, 3, 3, 2, 4, 3, 1, 1, 4, 2, 4, 0, 4,
#        0, 1, 0, 2, 3, 3, 0, 1, 0, 2, 3, 3, 0, 0, 0, 0, 3, 0, 1, 3, 4, 3,
#        2, 0, 0, 1, 2, 0, 2, 3, 1, 0, 4, 2, 4, 0, 3, 2, 0, 0, 3, 1, 0, 2,
#        4, 3, 2, 3, 0, 2, 2, 2, 3, 3, 4, 1, 4, 4, 2, 1, 1, 3, 3, 1, 0, 0,
#        1, 3, 2, 4, 2, 0, 0, 4, 2, 0, 0, 1, 2, 2, 2, 2, 2, 1, 2, 1, 4, 3,
#        0, 0, 1, 3, 3, 1, 3, 3, 4, 2, 3, 1, 1, 0, 2, 3, 3, 0, 1, 2, 2, 4,
#        3, 3, 2, 3, 3, 2, 0, 1, 3, 0, 0, 0, 4, 2, 0, 0, 0, 1, 3, 0, 1, 2,
#        1, 2, 4, 0, 0, 4, 2, 1, 0, 2, 3, 2, 0, 4, 3, 2, 1, 2, 3, 3, 2, 1,
#        4, 3, 3, 2, 3, 3, 1, 0, 3, 4, 3, 3, 3, 3, 1, 0, 0, 1, 4, 3, 2, 3,
#        0, 0, 4, 2, 0, 1, 2, 3, 0, 0, 4, 0, 0, 2, 4, 3, 2, 1, 0, 4, 3, 0,
#        3, 0, 3, 2, 1, 0, 4, 3, 2, 1, 2, 1, 2, 1, 3, 4, 1, 0, 3, 1, 1, 2,
#        2, 4, 4, 3, 4, 2, 4, 1, 4, 3, 1, 1, 0, 0, 4, 0, 3, 1, 2, 0, 0, 3,
#        1, 3, 0, 1, 4, 1, 1, 3, 1, 4, 4, 0, 4, 2, 2, 3, 3, 2, 0, 3, 4, 0,
#        4, 4, 3, 2, 2, 2, 1, 2, 3, 0, 1, 0, 2, 0, 2, 0, 2, 2, 1, 4, 0, 2,
#        3, 3, 2, 0, 4, 4, 2, 1, 3, 2, 4, 0, 3, 0, 4, 0, 2, 0, 0, 2, 0, 4,
#        0, 2, 4, 0, 0, 4, 4, 0, 2, 0, 0, 1, 1, 1, 3, 4, 2, 0, 3, 0, 3, 2,
#        1, 4, 0, 4, 1, 2, 1, 1, 0, 2, 3, 4, 3, 3, 3, 2, 0, 0, 0, 4, 1, 0,
#        4, 3, 3, 2, 2, 2, 1, 3, 3, 0, 3, 2, 4, 4, 3, 2, 3, 4, 1, 4, 1, 1,
#        1, 1, 3, 1, 2, 1, 4, 4, 1, 4, 0, 4, 2, 0, 3, 1, 0, 2, 2, 1, 3, 0,
#        4, 4, 1, 2, 0, 2, 3, 3, 2, 2, 3, 2, 1, 2, 2, 3, 3, 4, 2, 2, 1, 3,
#        2, 2, 4, 0, 4, 0, 3, 2, 4, 3, 1, 2, 4, 4, 3, 0, 4, 4, 3, 4, 2, 4,
#        0, 1, 2, 0, 3, 2, 3, 3, 2, 1, 0, 3, 1, 1, 1, 2, 0, 1, 0, 0, 3, 0,
#        3, 2, 0, 1, 1, 1, 3, 4, 0, 3, 0, 0, 1, 1, 1, 4, 4, 1, 2, 2, 1, 0,
#        3, 3, 1, 2, 2, 3, 1, 2, 1, 0, 2, 3, 2, 2, 3, 0, 1, 2, 3, 1, 3, 2,
#        2, 4, 1, 0, 2, 1, 0, 3, 3, 2, 1, 2, 4, 2, 0, 3, 3, 2, 0, 3, 3, 2,
#        2, 1, 3, 0, 1, 4, 4, 4, 1, 2, 4, 1, 2, 4, 3, 0, 1, 0, 0, 0, 3, 2,
#        2, 3, 4, 1, 1, 4, 1, 2, 1, 2])

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(test_labels,predictions.values, average='macro')
# Out:
# (0.8881407872362566, 0.8477962832126117, 0.8558527554029005, None)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.853

# %%
def accuracy_per_class(preds_flat, labels_flat):

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {LE.inverse_transform([label])}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 155/162
#
# Class: ['rec.sport.hockey']
# Accuracy: 172/175
#
# Class: ['sci.med']
# Accuracy: 212/309
#
# Class: ['sci.space']
# Accuracy: 186/224
#
# Class: ['talk.politics.misc']
# Accuracy: 128/130

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %%
# 80 20

bag_of_wrds_70_30 = joblib.load("selected_features_70_30")
train_70_30 = pd.read_csv("train_70_30_split.csv")
test_70_30 = pd.read_csv("test_70_30_split.csv")
LE = preprocessing.LabelEncoder()
train_70_30['label'] = LE.fit_transform(train_70_30['label'].values)
lookup_table_70_30 = train_naive_bayes(train_70_30['label'].values, list(set(train_70_30['label'].values)), bag_of_wrds_70_30)

# %%
joblib.dump(lookup_table_70_30,'lookup_table_70_30')
# Out:
# ['lookup_table_70_30']

# %%
test_70_30['text'] = test_70_30['text'].astype(str)

# %%
set(test_70_30['label'].values)
# Out:
# {'comp.graphics',
#  'rec.sport.hockey',
#  'sci.med',
#  'sci.space',
#  'talk.politics.misc'}

# %%
predictions = test_70_30['text'].apply(lambda x: test_naive_bayes(x, lookup_table_70_30))

# %%
test_labels = LE.transform(test_70_30['label'].values)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.84

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 227/238
#
# Class: ['rec.sport.hockey']
# Accuracy: 266/270
#
# Class: ['sci.med']
# Accuracy: 283/479
#
# Class: ['sci.space']
# Accuracy: 232/252
#
# Class: ['talk.politics.misc']
# Accuracy: 252/261

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %%
# 80 20

bag_of_wrds_50_50 = joblib.load("selected_features_50_50")
train_50_50 = pd.read_csv("train_50_50_split.csv")
test_50_50 = pd.read_csv("test_50_50_split.csv")
LE = preprocessing.LabelEncoder()
train_50_50['label'] = LE.fit_transform(train_50_50['label'].values)
lookup_table_50_50 = train_naive_bayes(train_50_50['label'].values, list(set(train_50_50['label'].values)), bag_of_wrds_50_50)

# %%
test_50_50['text'] = test_50_50['text'].astype(str)

# %%
set(test_50_50['label'].values)
# Out:
# {'comp.graphics',
#  'rec.sport.hockey',
#  'sci.med',
#  'sci.space',
#  'talk.politics.misc'}

# %%
predictions = test_50_50['text'].apply(lambda x: test_naive_bayes(x, lookup_table_50_50))

# %%
test_labels = LE.transform(test_50_50['label'].values)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels,predictions.values)
# Out:
# 0.8068

# %%
accuracy_per_class(test_labels,predictions.values)
# Out:
# Class: ['comp.graphics']
# Accuracy: 336/345
#
# Class: ['rec.sport.hockey']
# Accuracy: 418/422
#
# Class: ['sci.med']
# Accuracy: 519/810
#
# Class: ['sci.space']
# Accuracy: 460/633
#
# Class: ['talk.politics.misc']
# Accuracy: 284/290

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_labels, predictions.values)

df_cm = pd.DataFrame(conf_mat)
fig = plt.figure(figsize=(5,4))
class_names= [0,1,2,3,4]
ax = sn.set(font_scale=1.2) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 15}, cmap=plt.cm.Blues, fmt='g') # font size
ax.set(xlabel='Predicted Label', ylabel='True Label')
# labels, title and ticks
ax.xaxis.set_ticklabels(class_names); ax.yaxis.set_ticklabels(class_names);
fig.show()
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app
